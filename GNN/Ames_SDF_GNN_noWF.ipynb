# %%
### Pytorch geometry (グラフニューラルネットワークライブラリ) のインストール(only first time)
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
# ライブラリ確認
import numpy as np
import pandas as pd
import rdkit
from rdkit import Chem
import torch
from torch_geometric.data import Data as TorchGeometricData

print(Chem.__doc__)
# Out:
#  A module for molecules and stuff
#
#  see Chem/index.html in the doc tree for documentation

# %%
#SDFファイルの読み込み
import glob
import re

suppl  = Chem.SDMolSupplier("../../ForMolPredict/SDF_files/Ames/Ames_AllMol.sdf",removeHs=False) 
mol_list = [x for x in suppl]
mol_num = len(mol_list)
print("there are {} molecules".format(mol_num))
# Out:
# RDKit WARNING: [09:35:16] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:16] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:35:16] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:16] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# there are 6134 molecules
# RDKit WARNING: [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:35:17] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
#detaの分割
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(mol_list, random_state=0)
train, val = train_test_split(train_val)

# %%
## pandasのデータフレームからRDkitのmolオブジェクトXとラベルYのペアに変換

Xwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Ywf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
for mol in train: 
    Xwf["train"].append(mol)
    Ywf["train"].append(mol.GetDoubleProp('Activity'))
for mol in val: 
    Xwf["valid"].append(mol)
    Ywf["valid"].append(mol.GetDoubleProp('Activity'))
for mol in test:
    Xwf["test"].append(mol)
    Ywf["test"].append(mol.GetDoubleProp('Activity'))

# %%
def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception(
            "input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))


def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def get_atom_features(atom, en_list=None, explicit_H=False, use_sybyl=False, use_electronegativity=False,
                  use_gasteiger=False, degree_dim=17):
    if use_sybyl:
        atom_type = ordkit._sybyl_atom_type(atom)
        atom_list = ['C.ar', 'C.cat', 'C.1', 'C.2', 'C.3', 'N.ar', 'N.am', 'N.pl3', 'N.1', 'N.2', 'N.3', 'N.4', 'O.co2',
                     'O.2', 'O.3', 'S.O', 'S.o2', 'S.2', 'S.3', 'F', 'Si', 'P', 'P3', 'Cl', 'Br', 'Mg', 'Na', 'Ca',
                     'Fe', 'As', 'Al', 'I', 'B', 'V', 'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn',
                     'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni', 'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    else:
        atom_type = atom.GetSymbol()
        atom_list = ['C', 'N', 'O', 'S', 'F', 'Si', 'P', 'Cl', 'Br', 'Mg', 'Na', 'Ca', 'Fe', 'As', 'Al', 'I', 'B', 'V',
                     'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn', 'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni',
                     'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    results = one_of_k_encoding_unk(atom_type, atom_list) + \
        one_of_k_encoding(atom.GetDegree(), list(range(degree_dim))) + \
        one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3, 4, 5, 6]) + \
        [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + \
        one_of_k_encoding_unk(atom.GetHybridization(),
                              [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
                               Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.SP3D,
                               Chem.rdchem.HybridizationType.SP3D2]) + \
        [atom.GetIsAromatic()]

    if use_electronegativity:
        results = results + [en_list[atom.GetAtomicNum() - 1]]
    if use_gasteiger:
        gasteiger = atom.GetDoubleProp('_GasteigerCharge')
        if np.isnan(gasteiger) or np.isinf(gasteiger):
            gasteiger = 0  # because the mean is 0
        results = results + [gasteiger]

    # In case of explicit hydrogen(QM8, QM9), avoid calling `GetTotalNumHs`
    if not explicit_H:
        results = results + one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3, 4])
    return np.array(results, dtype=np.float32)

def get_bond_features(bond):
  results=one_of_k_encoding_unk(bond.GetBondType(),[Chem.rdchem.BondType.SINGLE,
                         Chem.rdchem.BondType.DOUBLE,
                         Chem.rdchem.BondType.TRIPLE,
                         Chem.rdchem.BondType.AROMATIC])
  return np.array(results, dtype=np.float32)

# %%
import torch
from rdkit import Chem
from torch_geometric.data import Data as TorchGeometricData
from torch_geometric.data import DataLoader

def get_edge_features(mol):
    edge_list= []
    num_bond_features=0
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        bond_features = get_bond_features(bond)
        num_bond_features=len(bond_features)
        edge_list += [([i, j],bond_features), ([j, i],bond_features)]
    return edge_list, num_bond_features

#modified mol2geodata
#規格化関数
def rescaling(features):
    norm_features = []
    max_value = max(features)
    min_value = min(features)
    for feature in features:
        norm_feature = (feature - min_value)/(max_value - min_value)
        norm_features.append(norm_feature)
    
    return norm_features

def get_WF_results(mol):
    mol_props = ['Volume', 'Energy', 'HOMO', 'LUMO', 'HLgap', 'Mcharge_ave', 'Mcharge_var', 'Lcharge_ave', 'Lcharge_var', 'dipole', 'Atom_num', 'Mass', 'Density']
    atom_props = ['Mcharges', 'Lcharges', 'Mass', 'X_dem', 'Y_dem', 'Z_dem']
    mol_datalist = []
    WF_results = []
    for mol_prop in mol_props:
        mol_datalist.append(mol.GetDoubleProp(mol_prop))
    for atom in mol.GetAtoms():
        atom_data = []
        for atom_prop in atom_props:
            atom_data.append(atom.GetDoubleProp(atom_prop))
            molatom_data = mol_datalist + atom_data
        WF_results.append(molatom_data)
    return np.array(WF_results, dtype=np.float32)

def mol2geodataWF(mol,y):
    smile = Chem.MolToSmiles(mol)
    atom_features =[get_atom_features(atom) for atom in mol.GetAtoms()]
    #WF_results = get_WF_results(mol)
    #atom_features = np.append(atom_features, WF_results, axis=1)
    num_atom_features=len(atom_features[0])
    atom_features = torch.FloatTensor(atom_features).view(-1, len(atom_features[0]))

    edge_list,num_bond_features = get_edge_features(mol)
    edge_list=sorted(edge_list)
    
    edge_indices=[e for e,v in edge_list]
    edge_attributes=[v for e,v in edge_list]
    edge_indices = torch.tensor(edge_indices)
    edge_indices = edge_indices.t().to(torch.long).view(2, -1)
    edge_attributes = torch.FloatTensor(edge_attributes)
    #print(num_atom_features,num_bond_features)
    return TorchGeometricData(x=atom_features, edge_index=edge_indices, edge_attr=edge_attributes, num_atom_features=num_atom_features,num_bond_features=num_bond_features,smiles=smile, y=y)

# %%
train_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["train"],Ywf["train"])]
train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)

valid_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["valid"],Ywf["valid"])]
valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)

test_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["test"],Ywf["test"])]
test_loader = DataLoader(test_data_list, batch_size=128,shuffle=True)
# Out:
# /home/kuma/anaconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/deprecation.py:13: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
num_atom_features = train_data_list[0].num_atom_features
num_bond_features = train_data_list[0].num_bond_features

print("num_atom_features =",num_atom_features)
print("num_bond_features =",num_bond_features)
# Out:
# num_atom_features = 81
# num_bond_features = 4

# %%
# ニューラルネットワークの構造の定義

import torch
import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU
import torch_geometric.transforms as T
from torch_geometric.nn import NNConv, Set2Set

dim = 64 # 中間層の次元

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.lin0 = torch.nn.Linear(num_atom_features, dim)

        nn = Sequential(Linear(num_bond_features, 128), ReLU(), Linear(128, dim * dim))
        self.conv = NNConv(dim, dim, nn, aggr='mean')
        self.gru = GRU(dim, dim)

        self.set2set = Set2Set(dim, processing_steps=3)
        self.lin1 = torch.nn.Linear(2 * dim, dim)
        self.lin2 = torch.nn.Linear(dim, 1)

    def forward(self, data):
        out = F.relu(self.lin0(data.x))
        h = out.unsqueeze(0)

        for i in range(3):
            m = F.relu(self.conv(out, data.edge_index, data.edge_attr))
            out, h = self.gru(m.unsqueeze(0), h)
            out = out.squeeze(0)

        out = self.set2set(out, data.batch)
        out = F.relu(self.lin1(out))
        out = self.lin2(out)
        return out.view(-1)

# %%
# ニューラルネットワークの学習パラメータの定義

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',factor=0.7, patience=5,min_lr=0.00001)
loss_function = torch.nn.BCEWithLogitsLoss()

def train_step(epoch):
    model.train()
    loss_all = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        loss = loss_function(model(data), data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_loader.dataset)

def test_step(loader):
    model.eval()
    loss_all = 0
    for data in loader:
        data = data.to(device)
        loss = loss_function(model(data), data.y)
        loss_all += loss.item() * data.num_graphs
    return loss_all / len(loader.dataset)

# %%
# 学習開始
Epoch_list = []
Loss_list = []
Val_list = []
Test_list =[]
best_valid_loss = None
for epoch in range(200):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train_step(epoch)
    valid_loss = test_step(valid_loader)
    scheduler.step(valid_loss)

    if best_valid_loss is None or valid_loss <= best_valid_loss:
        test_loss = test_step(test_loader)
        best_valid_loss = valid_loss
    Epoch_list.append(epoch)
    Loss_list.append(loss)
    Val_list.append(valid_loss)
    Test_list.append(test_loss)
    print('Epoch: {:03d}, LR: {:7f}, Loss: {:.7f}, Validation loss: {:.7f}, '
          'Test loss: {:.7f}'.format(epoch, lr, loss, valid_loss, test_loss))
# Out:
# Epoch: 000, LR: 0.001000, Loss: 0.6820187, Validation loss: 0.6770030, Test loss: 0.6798838
# Epoch: 001, LR: 0.001000, Loss: 0.6478755, Validation loss: 0.6454613, Test loss: 0.6504506
# Epoch: 002, LR: 0.001000, Loss: 0.6243069, Validation loss: 0.6198313, Test loss: 0.6147662
# Epoch: 003, LR: 0.001000, Loss: 0.5987043, Validation loss: 0.5904546, Test loss: 0.5939561
# Epoch: 004, LR: 0.001000, Loss: 0.5822083, Validation loss: 0.5879047, Test loss: 0.5865034
# Epoch: 005, LR: 0.001000, Loss: 0.5750908, Validation loss: 0.5919118, Test loss: 0.5865034
# Epoch: 006, LR: 0.001000, Loss: 0.5780796, Validation loss: 0.5877318, Test loss: 0.5839511
# Epoch: 007, LR: 0.001000, Loss: 0.5723507, Validation loss: 0.5741603, Test loss: 0.5752896
# Epoch: 008, LR: 0.001000, Loss: 0.5587341, Validation loss: 0.5650810, Test loss: 0.5669136
# Epoch: 009, LR: 0.001000, Loss: 0.5513812, Validation loss: 0.5535885, Test loss: 0.5553822
# Epoch: 010, LR: 0.001000, Loss: 0.5438516, Validation loss: 0.5540337, Test loss: 0.5553822
# Epoch: 011, LR: 0.001000, Loss: 0.5347015, Validation loss: 0.5458124, Test loss: 0.5400069
# Epoch: 012, LR: 0.001000, Loss: 0.5332078, Validation loss: 0.5293926, Test loss: 0.5306220
# Epoch: 013, LR: 0.001000, Loss: 0.5123938, Validation loss: 0.5211678, Test loss: 0.5133089
# Epoch: 014, LR: 0.001000, Loss: 0.5043605, Validation loss: 0.5215490, Test loss: 0.5133089
# Epoch: 015, LR: 0.001000, Loss: 0.4928986, Validation loss: 0.5352971, Test loss: 0.5133089
# Epoch: 016, LR: 0.001000, Loss: 0.4937051, Validation loss: 0.5115169, Test loss: 0.5127681
# Epoch: 017, LR: 0.001000, Loss: 0.4794252, Validation loss: 0.5160879, Test loss: 0.5127681
# Epoch: 018, LR: 0.001000, Loss: 0.4786443, Validation loss: 0.5110979, Test loss: 0.4972414
# Epoch: 019, LR: 0.001000, Loss: 0.4749759, Validation loss: 0.5089986, Test loss: 0.5128349
# Epoch: 020, LR: 0.001000, Loss: 0.4753557, Validation loss: 0.5041442, Test loss: 0.4828541
# Epoch: 021, LR: 0.001000, Loss: 0.4613485, Validation loss: 0.5011402, Test loss: 0.4746321
# Epoch: 022, LR: 0.001000, Loss: 0.4518604, Validation loss: 0.4962501, Test loss: 0.4796601
# Epoch: 023, LR: 0.001000, Loss: 0.4389422, Validation loss: 0.4951178, Test loss: 0.4901984
# Epoch: 024, LR: 0.001000, Loss: 0.4427164, Validation loss: 0.5074061, Test loss: 0.4901984
# Epoch: 025, LR: 0.001000, Loss: 0.4413970, Validation loss: 0.5000141, Test loss: 0.4901984
# Epoch: 026, LR: 0.001000, Loss: 0.4249597, Validation loss: 0.5129384, Test loss: 0.4901984
# Epoch: 027, LR: 0.001000, Loss: 0.4242858, Validation loss: 0.5184687, Test loss: 0.4901984
# Epoch: 028, LR: 0.001000, Loss: 0.4255300, Validation loss: 0.5074474, Test loss: 0.4901984
# Epoch: 029, LR: 0.001000, Loss: 0.4152292, Validation loss: 0.4926119, Test loss: 0.4843012
# Epoch: 030, LR: 0.001000, Loss: 0.4037757, Validation loss: 0.5149331, Test loss: 0.4843012
# Epoch: 031, LR: 0.001000, Loss: 0.4032126, Validation loss: 0.5262993, Test loss: 0.4843012
# Epoch: 032, LR: 0.001000, Loss: 0.3961748, Validation loss: 0.4892713, Test loss: 0.4655735
# Epoch: 033, LR: 0.001000, Loss: 0.3854011, Validation loss: 0.5148749, Test loss: 0.4655735
# Epoch: 034, LR: 0.001000, Loss: 0.3981991, Validation loss: 0.5130196, Test loss: 0.4655735
# Epoch: 035, LR: 0.001000, Loss: 0.3865600, Validation loss: 0.5081713, Test loss: 0.4655735
# Epoch: 036, LR: 0.001000, Loss: 0.3702779, Validation loss: 0.5036717, Test loss: 0.4655735
# Epoch: 037, LR: 0.001000, Loss: 0.3685994, Validation loss: 0.5369803, Test loss: 0.4655735
# Epoch: 038, LR: 0.001000, Loss: 0.3632969, Validation loss: 0.5125607, Test loss: 0.4655735
# Epoch: 039, LR: 0.000700, Loss: 0.3554605, Validation loss: 0.5458749, Test loss: 0.4655735
# Epoch: 040, LR: 0.000700, Loss: 0.3385342, Validation loss: 0.5325781, Test loss: 0.4655735
# Epoch: 041, LR: 0.000700, Loss: 0.3217058, Validation loss: 0.5493082, Test loss: 0.4655735
# Epoch: 042, LR: 0.000700, Loss: 0.3043571, Validation loss: 0.5582393, Test loss: 0.4655735
# Epoch: 043, LR: 0.000700, Loss: 0.3048131, Validation loss: 0.5434387, Test loss: 0.4655735
# Epoch: 044, LR: 0.000700, Loss: 0.3052751, Validation loss: 0.5874727, Test loss: 0.4655735
# Epoch: 045, LR: 0.000490, Loss: 0.2871760, Validation loss: 0.5742446, Test loss: 0.4655735
# Epoch: 046, LR: 0.000490, Loss: 0.2815561, Validation loss: 0.5840205, Test loss: 0.4655735
# Epoch: 047, LR: 0.000490, Loss: 0.2576530, Validation loss: 0.6089962, Test loss: 0.4655735
# Epoch: 048, LR: 0.000490, Loss: 0.2581101, Validation loss: 0.6178894, Test loss: 0.4655735
# Epoch: 049, LR: 0.000490, Loss: 0.2601865, Validation loss: 0.6187083, Test loss: 0.4655735
# Epoch: 050, LR: 0.000490, Loss: 0.2585671, Validation loss: 0.6202940, Test loss: 0.4655735
# Epoch: 051, LR: 0.000343, Loss: 0.2315625, Validation loss: 0.6380143, Test loss: 0.4655735
# Epoch: 052, LR: 0.000343, Loss: 0.2214081, Validation loss: 0.6563196, Test loss: 0.4655735
# Epoch: 053, LR: 0.000343, Loss: 0.2166885, Validation loss: 0.6630090, Test loss: 0.4655735
# Epoch: 054, LR: 0.000343, Loss: 0.2147542, Validation loss: 0.6605573, Test loss: 0.4655735
# Epoch: 055, LR: 0.000343, Loss: 0.2119605, Validation loss: 0.6717362, Test loss: 0.4655735
# Epoch: 056, LR: 0.000343, Loss: 0.1970382, Validation loss: 0.6938308, Test loss: 0.4655735
# Epoch: 057, LR: 0.000240, Loss: 0.1897096, Validation loss: 0.7091726, Test loss: 0.4655735
# Epoch: 058, LR: 0.000240, Loss: 0.1926635, Validation loss: 0.7125188, Test loss: 0.4655735
# Epoch: 059, LR: 0.000240, Loss: 0.1853146, Validation loss: 0.7240228, Test loss: 0.4655735
# Epoch: 060, LR: 0.000240, Loss: 0.1782821, Validation loss: 0.7317465, Test loss: 0.4655735
# Epoch: 061, LR: 0.000240, Loss: 0.1757693, Validation loss: 0.7329570, Test loss: 0.4655735
# Epoch: 062, LR: 0.000240, Loss: 0.1792307, Validation loss: 0.7543915, Test loss: 0.4655735
# Epoch: 063, LR: 0.000168, Loss: 0.1693137, Validation loss: 0.7661628, Test loss: 0.4655735
# Epoch: 064, LR: 0.000168, Loss: 0.1621618, Validation loss: 0.7791564, Test loss: 0.4655735
# Epoch: 065, LR: 0.000168, Loss: 0.1604182, Validation loss: 0.7813876, Test loss: 0.4655735
# Epoch: 066, LR: 0.000168, Loss: 0.1579847, Validation loss: 0.7916274, Test loss: 0.4655735
# Epoch: 067, LR: 0.000168, Loss: 0.1576014, Validation loss: 0.7952082, Test loss: 0.4655735
# Epoch: 068, LR: 0.000168, Loss: 0.1526324, Validation loss: 0.8077679, Test loss: 0.4655735
# Epoch: 069, LR: 0.000118, Loss: 0.1471142, Validation loss: 0.8119316, Test loss: 0.4655735
# Epoch: 070, LR: 0.000118, Loss: 0.1457043, Validation loss: 0.8117088, Test loss: 0.4655735
# Epoch: 071, LR: 0.000118, Loss: 0.1422903, Validation loss: 0.8184965, Test loss: 0.4655735
# Epoch: 072, LR: 0.000118, Loss: 0.1407447, Validation loss: 0.8280968, Test loss: 0.4655735
# Epoch: 073, LR: 0.000118, Loss: 0.1381659, Validation loss: 0.8393978, Test loss: 0.4655735
# Epoch: 074, LR: 0.000118, Loss: 0.1410811, Validation loss: 0.8532693, Test loss: 0.4655735
# Epoch: 075, LR: 0.000082, Loss: 0.1359636, Validation loss: 0.8438232, Test loss: 0.4655735
# Epoch: 076, LR: 0.000082, Loss: 0.1325961, Validation loss: 0.8533243, Test loss: 0.4655735
# Epoch: 077, LR: 0.000082, Loss: 0.1331544, Validation loss: 0.8540199, Test loss: 0.4655735
# Epoch: 078, LR: 0.000082, Loss: 0.1293187, Validation loss: 0.8611527, Test loss: 0.4655735
# Epoch: 079, LR: 0.000082, Loss: 0.1293127, Validation loss: 0.8654956, Test loss: 0.4655735
# Epoch: 080, LR: 0.000082, Loss: 0.1265660, Validation loss: 0.8747063, Test loss: 0.4655735
# Epoch: 081, LR: 0.000058, Loss: 0.1243943, Validation loss: 0.8816182, Test loss: 0.4655735
# Epoch: 082, LR: 0.000058, Loss: 0.1230086, Validation loss: 0.8824505, Test loss: 0.4655735
# Epoch: 083, LR: 0.000058, Loss: 0.1219355, Validation loss: 0.8902677, Test loss: 0.4655735
# Epoch: 084, LR: 0.000058, Loss: 0.1215887, Validation loss: 0.8919838, Test loss: 0.4655735
# Epoch: 085, LR: 0.000058, Loss: 0.1201863, Validation loss: 0.8967353, Test loss: 0.4655735
# Epoch: 086, LR: 0.000058, Loss: 0.1195980, Validation loss: 0.9004088, Test loss: 0.4655735
# Epoch: 087, LR: 0.000040, Loss: 0.1185258, Validation loss: 0.9034042, Test loss: 0.4655735
# Epoch: 088, LR: 0.000040, Loss: 0.1172706, Validation loss: 0.9098007, Test loss: 0.4655735
# Epoch: 089, LR: 0.000040, Loss: 0.1161545, Validation loss: 0.9134576, Test loss: 0.4655735
# Epoch: 090, LR: 0.000040, Loss: 0.1158855, Validation loss: 0.9147181, Test loss: 0.4655735
# Epoch: 091, LR: 0.000040, Loss: 0.1157721, Validation loss: 0.9189789, Test loss: 0.4655735
# Epoch: 092, LR: 0.000040, Loss: 0.1147802, Validation loss: 0.9218214, Test loss: 0.4655735
# Epoch: 093, LR: 0.000028, Loss: 0.1133790, Validation loss: 0.9229483, Test loss: 0.4655735
# Epoch: 094, LR: 0.000028, Loss: 0.1128792, Validation loss: 0.9246657, Test loss: 0.4655735
# Epoch: 095, LR: 0.000028, Loss: 0.1122877, Validation loss: 0.9257086, Test loss: 0.4655735
# Epoch: 096, LR: 0.000028, Loss: 0.1117687, Validation loss: 0.9294312, Test loss: 0.4655735
# Epoch: 097, LR: 0.000028, Loss: 0.1116171, Validation loss: 0.9315862, Test loss: 0.4655735
# Epoch: 098, LR: 0.000028, Loss: 0.1111860, Validation loss: 0.9348095, Test loss: 0.4655735
# Epoch: 099, LR: 0.000020, Loss: 0.1106992, Validation loss: 0.9342890, Test loss: 0.4655735
# Epoch: 100, LR: 0.000020, Loss: 0.1100733, Validation loss: 0.9371979, Test loss: 0.4655735
# Epoch: 101, LR: 0.000020, Loss: 0.1097503, Validation loss: 0.9384367, Test loss: 0.4655735
# Epoch: 102, LR: 0.000020, Loss: 0.1094824, Validation loss: 0.9388945, Test loss: 0.4655735
# Epoch: 103, LR: 0.000020, Loss: 0.1095192, Validation loss: 0.9409651, Test loss: 0.4655735
# Epoch: 104, LR: 0.000020, Loss: 0.1088673, Validation loss: 0.9432719, Test loss: 0.4655735
# Epoch: 105, LR: 0.000014, Loss: 0.1083730, Validation loss: 0.9426248, Test loss: 0.4655735
# Epoch: 106, LR: 0.000014, Loss: 0.1082031, Validation loss: 0.9456796, Test loss: 0.4655735
# Epoch: 107, LR: 0.000014, Loss: 0.1078492, Validation loss: 0.9480443, Test loss: 0.4655735
# Epoch: 108, LR: 0.000014, Loss: 0.1076283, Validation loss: 0.9470706, Test loss: 0.4655735
# Epoch: 109, LR: 0.000014, Loss: 0.1074183, Validation loss: 0.9488247, Test loss: 0.4655735
# Epoch: 110, LR: 0.000014, Loss: 0.1074678, Validation loss: 0.9500931, Test loss: 0.4655735
# Epoch: 111, LR: 0.000010, Loss: 0.1071568, Validation loss: 0.9506641, Test loss: 0.4655735
# Epoch: 112, LR: 0.000010, Loss: 0.1068147, Validation loss: 0.9513491, Test loss: 0.4655735
# Epoch: 113, LR: 0.000010, Loss: 0.1067467, Validation loss: 0.9521117, Test loss: 0.4655735
# Epoch: 114, LR: 0.000010, Loss: 0.1065545, Validation loss: 0.9522473, Test loss: 0.4655735
# Epoch: 115, LR: 0.000010, Loss: 0.1063644, Validation loss: 0.9537411, Test loss: 0.4655735
# Epoch: 116, LR: 0.000010, Loss: 0.1064156, Validation loss: 0.9547192, Test loss: 0.4655735
# Epoch: 117, LR: 0.000010, Loss: 0.1061580, Validation loss: 0.9553517, Test loss: 0.4655735
# Epoch: 118, LR: 0.000010, Loss: 0.1060242, Validation loss: 0.9566148, Test loss: 0.4655735
# Epoch: 119, LR: 0.000010, Loss: 0.1060234, Validation loss: 0.9574310, Test loss: 0.4655735
# Epoch: 120, LR: 0.000010, Loss: 0.1057266, Validation loss: 0.9578311, Test loss: 0.4655735
# Epoch: 121, LR: 0.000010, Loss: 0.1056614, Validation loss: 0.9575171, Test loss: 0.4655735
# Epoch: 122, LR: 0.000010, Loss: 0.1054547, Validation loss: 0.9596490, Test loss: 0.4655735
# Epoch: 123, LR: 0.000010, Loss: 0.1054606, Validation loss: 0.9605613, Test loss: 0.4655735
# Epoch: 124, LR: 0.000010, Loss: 0.1053328, Validation loss: 0.9609355, Test loss: 0.4655735
# Epoch: 125, LR: 0.000010, Loss: 0.1052256, Validation loss: 0.9623032, Test loss: 0.4655735
# Epoch: 126, LR: 0.000010, Loss: 0.1050855, Validation loss: 0.9629328, Test loss: 0.4655735
# Epoch: 127, LR: 0.000010, Loss: 0.1049479, Validation loss: 0.9633779, Test loss: 0.4655735
# Epoch: 128, LR: 0.000010, Loss: 0.1047888, Validation loss: 0.9642055, Test loss: 0.4655735
# Epoch: 129, LR: 0.000010, Loss: 0.1046559, Validation loss: 0.9651605, Test loss: 0.4655735
# Epoch: 130, LR: 0.000010, Loss: 0.1045516, Validation loss: 0.9656015, Test loss: 0.4655735
# Epoch: 131, LR: 0.000010, Loss: 0.1044616, Validation loss: 0.9674593, Test loss: 0.4655735
# Epoch: 132, LR: 0.000010, Loss: 0.1042139, Validation loss: 0.9679441, Test loss: 0.4655735
# Epoch: 133, LR: 0.000010, Loss: 0.1041189, Validation loss: 0.9684357, Test loss: 0.4655735
# Epoch: 134, LR: 0.000010, Loss: 0.1038756, Validation loss: 0.9698644, Test loss: 0.4655735
# Epoch: 135, LR: 0.000010, Loss: 0.1038925, Validation loss: 0.9713803, Test loss: 0.4655735
# Epoch: 136, LR: 0.000010, Loss: 0.1037761, Validation loss: 0.9715442, Test loss: 0.4655735
# Epoch: 137, LR: 0.000010, Loss: 0.1035684, Validation loss: 0.9713857, Test loss: 0.4655735
# Epoch: 138, LR: 0.000010, Loss: 0.1034559, Validation loss: 0.9736368, Test loss: 0.4655735
# Epoch: 139, LR: 0.000010, Loss: 0.1032640, Validation loss: 0.9746249, Test loss: 0.4655735
# Epoch: 140, LR: 0.000010, Loss: 0.1034809, Validation loss: 0.9751046, Test loss: 0.4655735
# Epoch: 141, LR: 0.000010, Loss: 0.1030941, Validation loss: 0.9756850, Test loss: 0.4655735
# Epoch: 142, LR: 0.000010, Loss: 0.1029000, Validation loss: 0.9767150, Test loss: 0.4655735
# Epoch: 143, LR: 0.000010, Loss: 0.1030200, Validation loss: 0.9769252, Test loss: 0.4655735
# Epoch: 144, LR: 0.000010, Loss: 0.1027191, Validation loss: 0.9785923, Test loss: 0.4655735
# Epoch: 145, LR: 0.000010, Loss: 0.1024991, Validation loss: 0.9794432, Test loss: 0.4655735
# Epoch: 146, LR: 0.000010, Loss: 0.1024127, Validation loss: 0.9798679, Test loss: 0.4655735
# Epoch: 147, LR: 0.000010, Loss: 0.1022592, Validation loss: 0.9810678, Test loss: 0.4655735
# Epoch: 148, LR: 0.000010, Loss: 0.1020713, Validation loss: 0.9821066, Test loss: 0.4655735
# Epoch: 149, LR: 0.000010, Loss: 0.1020339, Validation loss: 0.9832268, Test loss: 0.4655735
# Epoch: 150, LR: 0.000010, Loss: 0.1017886, Validation loss: 0.9828921, Test loss: 0.4655735
# Epoch: 151, LR: 0.000010, Loss: 0.1016888, Validation loss: 0.9849813, Test loss: 0.4655735
# Epoch: 152, LR: 0.000010, Loss: 0.1016033, Validation loss: 0.9857091, Test loss: 0.4655735
# Epoch: 153, LR: 0.000010, Loss: 0.1013639, Validation loss: 0.9861977, Test loss: 0.4655735
# Epoch: 154, LR: 0.000010, Loss: 0.1012612, Validation loss: 0.9865087, Test loss: 0.4655735
# Epoch: 155, LR: 0.000010, Loss: 0.1012948, Validation loss: 0.9884035, Test loss: 0.4655735
# Epoch: 156, LR: 0.000010, Loss: 0.1012229, Validation loss: 0.9874596, Test loss: 0.4655735
# Epoch: 157, LR: 0.000010, Loss: 0.1010487, Validation loss: 0.9887264, Test loss: 0.4655735
# Epoch: 158, LR: 0.000010, Loss: 0.1009911, Validation loss: 0.9893095, Test loss: 0.4655735
# Epoch: 159, LR: 0.000010, Loss: 0.1008553, Validation loss: 0.9921305, Test loss: 0.4655735
# Epoch: 160, LR: 0.000010, Loss: 0.1005623, Validation loss: 0.9918233, Test loss: 0.4655735
# Epoch: 161, LR: 0.000010, Loss: 0.1006896, Validation loss: 0.9928317, Test loss: 0.4655735
# Epoch: 162, LR: 0.000010, Loss: 0.1001326, Validation loss: 0.9926432, Test loss: 0.4655735
# Epoch: 163, LR: 0.000010, Loss: 0.0998199, Validation loss: 0.9950111, Test loss: 0.4655735
# Epoch: 164, LR: 0.000010, Loss: 0.0999214, Validation loss: 0.9965020, Test loss: 0.4655735
# Epoch: 165, LR: 0.000010, Loss: 0.1000250, Validation loss: 0.9963730, Test loss: 0.4655735
# Epoch: 166, LR: 0.000010, Loss: 0.1006775, Validation loss: 0.9958051, Test loss: 0.4655735
# Epoch: 167, LR: 0.000010, Loss: 0.0993045, Validation loss: 0.9967062, Test loss: 0.4655735
# Epoch: 168, LR: 0.000010, Loss: 0.0991638, Validation loss: 0.9991078, Test loss: 0.4655735
# Epoch: 169, LR: 0.000010, Loss: 0.0989406, Validation loss: 1.0001166, Test loss: 0.4655735
# Epoch: 170, LR: 0.000010, Loss: 0.0991941, Validation loss: 0.9994342, Test loss: 0.4655735
# Epoch: 171, LR: 0.000010, Loss: 0.0985212, Validation loss: 1.0003069, Test loss: 0.4655735
# Epoch: 172, LR: 0.000010, Loss: 0.0983413, Validation loss: 1.0025443, Test loss: 0.4655735
# Epoch: 173, LR: 0.000010, Loss: 0.0982450, Validation loss: 1.0028964, Test loss: 0.4655735
# Epoch: 174, LR: 0.000010, Loss: 0.0979617, Validation loss: 1.0040614, Test loss: 0.4655735
# Epoch: 175, LR: 0.000010, Loss: 0.0979337, Validation loss: 1.0057996, Test loss: 0.4655735
# Epoch: 176, LR: 0.000010, Loss: 0.0977668, Validation loss: 1.0052832, Test loss: 0.4655735
# Epoch: 177, LR: 0.000010, Loss: 0.0977264, Validation loss: 1.0056411, Test loss: 0.4655735
# Epoch: 178, LR: 0.000010, Loss: 0.0973656, Validation loss: 1.0067528, Test loss: 0.4655735
# Epoch: 179, LR: 0.000010, Loss: 0.0974991, Validation loss: 1.0086874, Test loss: 0.4655735
# Epoch: 180, LR: 0.000010, Loss: 0.0972487, Validation loss: 1.0078855, Test loss: 0.4655735
# Epoch: 181, LR: 0.000010, Loss: 0.0970866, Validation loss: 1.0107649, Test loss: 0.4655735
# Epoch: 182, LR: 0.000010, Loss: 0.0968516, Validation loss: 1.0103867, Test loss: 0.4655735
# Epoch: 183, LR: 0.000010, Loss: 0.0968420, Validation loss: 1.0110509, Test loss: 0.4655735
# Epoch: 184, LR: 0.000010, Loss: 0.0967640, Validation loss: 1.0122985, Test loss: 0.4655735
# Epoch: 185, LR: 0.000010, Loss: 0.0967028, Validation loss: 1.0131923, Test loss: 0.4655735
# Epoch: 186, LR: 0.000010, Loss: 0.0966289, Validation loss: 1.0124853, Test loss: 0.4655735
# Epoch: 187, LR: 0.000010, Loss: 0.0963478, Validation loss: 1.0141368, Test loss: 0.4655735
# Epoch: 188, LR: 0.000010, Loss: 0.0962885, Validation loss: 1.0155434, Test loss: 0.4655735
# Epoch: 189, LR: 0.000010, Loss: 0.0960443, Validation loss: 1.0162677, Test loss: 0.4655735
# Epoch: 190, LR: 0.000010, Loss: 0.0959155, Validation loss: 1.0166540, Test loss: 0.4655735
# Epoch: 191, LR: 0.000010, Loss: 0.0958713, Validation loss: 1.0178785, Test loss: 0.4655735
# Epoch: 192, LR: 0.000010, Loss: 0.0957669, Validation loss: 1.0178555, Test loss: 0.4655735
# Epoch: 193, LR: 0.000010, Loss: 0.0955940, Validation loss: 1.0189602, Test loss: 0.4655735
# Epoch: 194, LR: 0.000010, Loss: 0.0954335, Validation loss: 1.0193220, Test loss: 0.4655735
# Epoch: 195, LR: 0.000010, Loss: 0.0954024, Validation loss: 1.0209765, Test loss: 0.4655735
# Epoch: 196, LR: 0.000010, Loss: 0.0952225, Validation loss: 1.0220385, Test loss: 0.4655735
# Epoch: 197, LR: 0.000010, Loss: 0.0950237, Validation loss: 1.0228073, Test loss: 0.4655735
# Epoch: 198, LR: 0.000010, Loss: 0.0950804, Validation loss: 1.0232828, Test loss: 0.4655735
# Epoch: 199, LR: 0.000010, Loss: 0.0948652, Validation loss: 1.0242013, Test loss: 0.4655735

# %%
#グラフ化
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.plot(Epoch_list, Loss_list, label = 'Loss')
plt.plot(Epoch_list, Val_list, label = 'Validation loss')
plt.plot(Epoch_list, Test_list, label = 'Test loss')

# 凡例を表示
plt.legend(loc=5)

# 軸ラベル
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()

# %%
#1~50
plt.plot(Epoch_list[0:51], Loss_list[0:51], label = 'Loss')
plt.plot(Epoch_list[0:51], Val_list[0:51], label = 'Validation loss')
plt.plot(Epoch_list[0:51], Test_list[0:51], label = 'Test loss')

# 凡例を表示
plt.legend(loc='lower left')

# 軸ラベル
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()
