# %%
### Pytorch geometry (グラフニューラルネットワークライブラリ) のインストール(only first time)
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
# ライブラリ確認
import numpy as np
import pandas as pd
import rdkit
from rdkit import Chem
import torch
from torch_geometric.data import Data as TorchGeometricData

print(Chem.__doc__)
# Out:
#  A module for molecules and stuff
#
#  see Chem/index.html in the doc tree for documentation

# %%
#SDFファイルの読み込み
import glob
import re

suppl  = Chem.SDMolSupplier("../../ForMolPredict/SDF_files/Ames/Ames_AllMol.sdf",removeHs=False) 
mol_list = [x for x in suppl]
mol_num = len(mol_list)
print("there are {} molecules".format(mol_num))
# Out:
# RDKit WARNING: [09:21:12] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:12] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:13] Warning: molecule is tagged as 3D, but all Z coords are zero
# there are 6134 molecules
# RDKit WARNING: [09:21:14] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:14] Warning: molecule is tagged as 3D, but all Z coords are zero
# RDKit WARNING: [09:21:14] Warning: molecule is tagged as 3D, but all Z coords are zero
# [09:21:14] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
#detaの分割
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(mol_list, random_state=0)
train, val = train_test_split(train_val)

# %%
## pandasのデータフレームからRDkitのmolオブジェクトXとラベルYのペアに変換

Xwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Ywf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
for mol in train: 
    Xwf["train"].append(mol)
    Ywf["train"].append(mol.GetDoubleProp('Activity'))
for mol in val: 
    Xwf["valid"].append(mol)
    Ywf["valid"].append(mol.GetDoubleProp('Activity'))
for mol in test:
    Xwf["test"].append(mol)
    Ywf["test"].append(mol.GetDoubleProp('Activity'))

# %%
def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception(
            "input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))


def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def get_atom_features(atom, en_list=None, explicit_H=False, use_sybyl=False, use_electronegativity=False,
                  use_gasteiger=False, degree_dim=17):
    if use_sybyl:
        atom_type = ordkit._sybyl_atom_type(atom)
        atom_list = ['C.ar', 'C.cat', 'C.1', 'C.2', 'C.3', 'N.ar', 'N.am', 'N.pl3', 'N.1', 'N.2', 'N.3', 'N.4', 'O.co2',
                     'O.2', 'O.3', 'S.O', 'S.o2', 'S.2', 'S.3', 'F', 'Si', 'P', 'P3', 'Cl', 'Br', 'Mg', 'Na', 'Ca',
                     'Fe', 'As', 'Al', 'I', 'B', 'V', 'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn',
                     'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni', 'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    else:
        atom_type = atom.GetSymbol()
        atom_list = ['C', 'N', 'O', 'S', 'F', 'Si', 'P', 'Cl', 'Br', 'Mg', 'Na', 'Ca', 'Fe', 'As', 'Al', 'I', 'B', 'V',
                     'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn', 'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni',
                     'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    results = one_of_k_encoding_unk(atom_type, atom_list) + \
        one_of_k_encoding(atom.GetDegree(), list(range(degree_dim))) + \
        one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3, 4, 5, 6]) + \
        [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + \
        one_of_k_encoding_unk(atom.GetHybridization(),
                              [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
                               Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.SP3D,
                               Chem.rdchem.HybridizationType.SP3D2]) + \
        [atom.GetIsAromatic()]

    if use_electronegativity:
        results = results + [en_list[atom.GetAtomicNum() - 1]]
    if use_gasteiger:
        gasteiger = atom.GetDoubleProp('_GasteigerCharge')
        if np.isnan(gasteiger) or np.isinf(gasteiger):
            gasteiger = 0  # because the mean is 0
        results = results + [gasteiger]

    # In case of explicit hydrogen(QM8, QM9), avoid calling `GetTotalNumHs`
    if not explicit_H:
        results = results + one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3, 4])
    return np.array(results, dtype=np.float32)

def get_bond_features(bond):
  results=one_of_k_encoding_unk(bond.GetBondType(),[Chem.rdchem.BondType.SINGLE,
                         Chem.rdchem.BondType.DOUBLE,
                         Chem.rdchem.BondType.TRIPLE,
                         Chem.rdchem.BondType.AROMATIC])
  return np.array(results, dtype=np.float32)

# %%
import torch
from rdkit import Chem
from torch_geometric.data import Data as TorchGeometricData
from torch_geometric.data import DataLoader

def get_edge_features(mol):
    edge_list= []
    num_bond_features=0
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        bond_features = get_bond_features(bond)
        num_bond_features=len(bond_features)
        edge_list += [([i, j],bond_features), ([j, i],bond_features)]
    return edge_list, num_bond_features

#modified mol2geodata
#規格化関数
def rescaling(features):
    norm_features = []
    max_value = max(features)
    min_value = min(features)
    for feature in features:
        norm_feature = (feature - min_value)/(max_value - min_value)
        norm_features.append(norm_feature)
    
    return norm_features

def get_WF_results(mol):
    mol_props = ['Volume', 'Energy', 'HOMO', 'LUMO', 'HLgap', 'Mcharge_ave', 'Mcharge_var', 'Lcharge_ave', 'Lcharge_var', 'dipole', 'Atom_num', 'Mass', 'Density']
    atom_props = ['Mcharges', 'Lcharges', 'Mass', 'X_dem', 'Y_dem', 'Z_dem']
    mol_datalist = []
    WF_results = []
    for mol_prop in mol_props:
        mol_datalist.append(mol.GetDoubleProp(mol_prop))
    for atom in mol.GetAtoms():
        atom_data = []
        for atom_prop in atom_props:
            atom_data.append(atom.GetDoubleProp(atom_prop))
            molatom_data = mol_datalist + atom_data
        WF_results.append(molatom_data)
    return np.array(WF_results, dtype=np.float32)

def mol2geodataWF(mol,y):
    smile = Chem.MolToSmiles(mol)
    atom_features =[get_atom_features(atom) for atom in mol.GetAtoms()]
    WF_results = get_WF_results(mol)
    atom_features = np.append(atom_features, WF_results, axis=1)
    num_atom_features=len(atom_features[0])
    atom_features = torch.FloatTensor(atom_features).view(-1, len(atom_features[0]))

    edge_list,num_bond_features = get_edge_features(mol)
    edge_list=sorted(edge_list)
    
    edge_indices=[e for e,v in edge_list]
    edge_attributes=[v for e,v in edge_list]
    edge_indices = torch.tensor(edge_indices)
    edge_indices = edge_indices.t().to(torch.long).view(2, -1)
    edge_attributes = torch.FloatTensor(edge_attributes)
    #print(num_atom_features,num_bond_features)
    return TorchGeometricData(x=atom_features, edge_index=edge_indices, edge_attr=edge_attributes, num_atom_features=num_atom_features,num_bond_features=num_bond_features,smiles=smile, y=y)

# %%
train_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["train"],Ywf["train"])]
train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)

valid_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["valid"],Ywf["valid"])]
valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)

test_data_list = [mol2geodataWF(mol,y) for mol,y in zip(Xwf["test"],Ywf["test"])]
test_loader = DataLoader(test_data_list, batch_size=128,shuffle=True)

# %%
num_atom_features = train_data_list[0].num_atom_features
num_bond_features = train_data_list[0].num_bond_features

print("num_atom_features =",num_atom_features)
print("num_bond_features =",num_bond_features)
# Out:
# num_atom_features = 100
# num_bond_features = 4

# %%
# ニューラルネットワークの構造の定義

import torch
import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU
import torch_geometric.transforms as T
from torch_geometric.nn import NNConv, Set2Set

dim = 64 # 中間層の次元

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.lin0 = torch.nn.Linear(num_atom_features, dim)

        nn = Sequential(Linear(num_bond_features, 128), ReLU(), Linear(128, dim * dim))
        self.conv = NNConv(dim, dim, nn, aggr='mean')
        self.gru = GRU(dim, dim)

        self.set2set = Set2Set(dim, processing_steps=3)
        self.lin1 = torch.nn.Linear(2 * dim, dim)
        self.lin2 = torch.nn.Linear(dim, 1)

    def forward(self, data):
        out = F.relu(self.lin0(data.x))
        h = out.unsqueeze(0)

        for i in range(3):
            m = F.relu(self.conv(out, data.edge_index, data.edge_attr))
            out, h = self.gru(m.unsqueeze(0), h)
            out = out.squeeze(0)

        out = self.set2set(out, data.batch)
        out = F.relu(self.lin1(out))
        out = self.lin2(out)
        return out.view(-1)

# %%
# ニューラルネットワークの学習パラメータの定義

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',factor=0.7, patience=5,min_lr=0.00001)
loss_function = torch.nn.BCEWithLogitsLoss()

def train_step(epoch):
    model.train()
    loss_all = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        loss = loss_function(model(data), data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_loader.dataset)

def test_step(loader):
    model.eval()
    loss_all = 0
    for data in loader:
        data = data.to(device)
        loss = loss_function(model(data), data.y)
        loss_all += loss.item() * data.num_graphs
    return loss_all / len(loader.dataset)

# %%
# 学習開始
Epoch_list = []
Loss_list = []
Val_list = []
Test_list =[]
best_valid_loss = None
for epoch in range(200):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train_step(epoch)
    valid_loss = test_step(valid_loader)
    scheduler.step(valid_loss)

    if best_valid_loss is None or valid_loss <= best_valid_loss:
        test_loss = test_step(test_loader)
        best_valid_loss = valid_loss
    Epoch_list.append(epoch)
    Loss_list.append(loss)
    Val_list.append(valid_loss)
    Test_list.append(test_loss)
    print('Epoch: {:03d}, LR: {:7f}, Loss: {:.7f}, Validation loss: {:.7f}, '
          'Test loss: {:.7f}'.format(epoch, lr, loss, valid_loss, test_loss))
# Out:
# Epoch: 000, LR: 0.001000, Loss: 0.7645617, Validation loss: 0.7183122, Test loss: 0.7352726
# Epoch: 001, LR: 0.001000, Loss: 0.6825154, Validation loss: 0.7022208, Test loss: 0.6796272
# Epoch: 002, LR: 0.001000, Loss: 0.6721200, Validation loss: 0.6520943, Test loss: 0.6529780
# Epoch: 003, LR: 0.001000, Loss: 0.6721805, Validation loss: 0.6600907, Test loss: 0.6529780
# Epoch: 004, LR: 0.001000, Loss: 0.6412330, Validation loss: 0.7688083, Test loss: 0.6529780
# Epoch: 005, LR: 0.001000, Loss: 0.6536979, Validation loss: 0.6542495, Test loss: 0.6529780
# Epoch: 006, LR: 0.001000, Loss: 0.6333207, Validation loss: 0.6547304, Test loss: 0.6529780
# Epoch: 007, LR: 0.001000, Loss: 0.6323230, Validation loss: 0.6409377, Test loss: 0.6509432
# Epoch: 008, LR: 0.001000, Loss: 0.6210711, Validation loss: 0.6427935, Test loss: 0.6509432
# Epoch: 009, LR: 0.001000, Loss: 0.6338825, Validation loss: 0.6552390, Test loss: 0.6509432
# Epoch: 010, LR: 0.001000, Loss: 0.6193138, Validation loss: 0.6375517, Test loss: 0.6371776
# Epoch: 011, LR: 0.001000, Loss: 0.6247524, Validation loss: 0.6951958, Test loss: 0.6371776
# Epoch: 012, LR: 0.001000, Loss: 0.6171194, Validation loss: 0.6924662, Test loss: 0.6371776
# Epoch: 013, LR: 0.001000, Loss: 0.6278959, Validation loss: 0.6312602, Test loss: 0.6231847
# Epoch: 014, LR: 0.001000, Loss: 0.6103777, Validation loss: 0.6290858, Test loss: 0.6201872
# Epoch: 015, LR: 0.001000, Loss: 0.6154781, Validation loss: 0.6876255, Test loss: 0.6201872
# Epoch: 016, LR: 0.001000, Loss: 0.6119330, Validation loss: 0.6364007, Test loss: 0.6201872
# Epoch: 017, LR: 0.001000, Loss: 0.6054613, Validation loss: 0.6398132, Test loss: 0.6201872
# Epoch: 018, LR: 0.001000, Loss: 0.6030943, Validation loss: 0.6428833, Test loss: 0.6201872
# Epoch: 019, LR: 0.001000, Loss: 0.6010227, Validation loss: 0.6787471, Test loss: 0.6201872
# Epoch: 020, LR: 0.001000, Loss: 0.6034393, Validation loss: 0.6219963, Test loss: 0.6134102
# Epoch: 021, LR: 0.001000, Loss: 0.5990856, Validation loss: 0.6805866, Test loss: 0.6134102
# Epoch: 022, LR: 0.001000, Loss: 0.6115369, Validation loss: 0.6658767, Test loss: 0.6134102
# Epoch: 023, LR: 0.001000, Loss: 0.6088616, Validation loss: 0.6422978, Test loss: 0.6134102
# Epoch: 024, LR: 0.001000, Loss: 0.6033089, Validation loss: 0.6423552, Test loss: 0.6134102
# Epoch: 025, LR: 0.001000, Loss: 0.5958891, Validation loss: 0.6432725, Test loss: 0.6134102
# Epoch: 026, LR: 0.001000, Loss: 0.5956226, Validation loss: 0.6334789, Test loss: 0.6134102
# Epoch: 027, LR: 0.000700, Loss: 0.5946834, Validation loss: 0.6603632, Test loss: 0.6134102
# Epoch: 028, LR: 0.000700, Loss: 0.5900159, Validation loss: 0.6161496, Test loss: 0.5968358
# Epoch: 029, LR: 0.000700, Loss: 0.5835543, Validation loss: 0.6337075, Test loss: 0.5968358
# Epoch: 030, LR: 0.000700, Loss: 0.5832593, Validation loss: 0.6260014, Test loss: 0.5968358
# Epoch: 031, LR: 0.000700, Loss: 0.5819530, Validation loss: 0.6196568, Test loss: 0.5968358
# Epoch: 032, LR: 0.000700, Loss: 0.5897674, Validation loss: 0.6242666, Test loss: 0.5968358
# Epoch: 033, LR: 0.000700, Loss: 0.5987055, Validation loss: 0.6422904, Test loss: 0.5968358
# Epoch: 034, LR: 0.000700, Loss: 0.5858618, Validation loss: 0.6196988, Test loss: 0.5968358
# Epoch: 035, LR: 0.000490, Loss: 0.5812165, Validation loss: 0.6308347, Test loss: 0.5968358
# Epoch: 036, LR: 0.000490, Loss: 0.5775043, Validation loss: 0.6391524, Test loss: 0.5968358
# Epoch: 037, LR: 0.000490, Loss: 0.5755545, Validation loss: 0.6618109, Test loss: 0.5968358
# Epoch: 038, LR: 0.000490, Loss: 0.5852082, Validation loss: 0.6235379, Test loss: 0.5968358
# Epoch: 039, LR: 0.000490, Loss: 0.5694771, Validation loss: 0.6401574, Test loss: 0.5968358
# Epoch: 040, LR: 0.000490, Loss: 0.5655766, Validation loss: 0.6180235, Test loss: 0.5968358
# Epoch: 041, LR: 0.000343, Loss: 0.5674591, Validation loss: 0.6237394, Test loss: 0.5968358
# Epoch: 042, LR: 0.000343, Loss: 0.5790992, Validation loss: 0.6260324, Test loss: 0.5968358
# Epoch: 043, LR: 0.000343, Loss: 0.5647083, Validation loss: 0.6035019, Test loss: 0.5879401
# Epoch: 044, LR: 0.000343, Loss: 0.5624036, Validation loss: 0.6369824, Test loss: 0.5879401
# Epoch: 045, LR: 0.000343, Loss: 0.5707506, Validation loss: 0.6244732, Test loss: 0.5879401
# Epoch: 046, LR: 0.000343, Loss: 0.5636785, Validation loss: 0.6100429, Test loss: 0.5879401
# Epoch: 047, LR: 0.000343, Loss: 0.5671429, Validation loss: 0.6163418, Test loss: 0.5879401
# Epoch: 048, LR: 0.000343, Loss: 0.5622662, Validation loss: 0.6099832, Test loss: 0.5879401
# Epoch: 049, LR: 0.000343, Loss: 0.5649676, Validation loss: 0.6000130, Test loss: 0.5834063
# Epoch: 050, LR: 0.000343, Loss: 0.5631490, Validation loss: 0.6166141, Test loss: 0.5834063
# Epoch: 051, LR: 0.000343, Loss: 0.5626618, Validation loss: 0.6112873, Test loss: 0.5834063
# Epoch: 052, LR: 0.000343, Loss: 0.5624656, Validation loss: 0.6274884, Test loss: 0.5834063
# Epoch: 053, LR: 0.000343, Loss: 0.5652366, Validation loss: 0.6120012, Test loss: 0.5834063
# Epoch: 054, LR: 0.000343, Loss: 0.5605569, Validation loss: 0.6053812, Test loss: 0.5834063
# Epoch: 055, LR: 0.000343, Loss: 0.5596707, Validation loss: 0.6045022, Test loss: 0.5834063
# Epoch: 056, LR: 0.000240, Loss: 0.5591292, Validation loss: 0.6099333, Test loss: 0.5834063
# Epoch: 057, LR: 0.000240, Loss: 0.5550690, Validation loss: 0.6162240, Test loss: 0.5834063
# Epoch: 058, LR: 0.000240, Loss: 0.5546090, Validation loss: 0.6190415, Test loss: 0.5834063
# Epoch: 059, LR: 0.000240, Loss: 0.5524358, Validation loss: 0.6305951, Test loss: 0.5834063
# Epoch: 060, LR: 0.000240, Loss: 0.5576634, Validation loss: 0.6061145, Test loss: 0.5834063
# Epoch: 061, LR: 0.000240, Loss: 0.5567527, Validation loss: 0.6234532, Test loss: 0.5834063
# Epoch: 062, LR: 0.000168, Loss: 0.5546773, Validation loss: 0.6143523, Test loss: 0.5834063
# Epoch: 063, LR: 0.000168, Loss: 0.5514702, Validation loss: 0.6107796, Test loss: 0.5834063
# Epoch: 064, LR: 0.000168, Loss: 0.5536110, Validation loss: 0.6200581, Test loss: 0.5834063
# Epoch: 065, LR: 0.000168, Loss: 0.5522284, Validation loss: 0.6176047, Test loss: 0.5834063
# Epoch: 066, LR: 0.000168, Loss: 0.5495775, Validation loss: 0.6118804, Test loss: 0.5834063
# Epoch: 067, LR: 0.000168, Loss: 0.5506274, Validation loss: 0.6086325, Test loss: 0.5834063
# Epoch: 068, LR: 0.000118, Loss: 0.5500407, Validation loss: 0.6069220, Test loss: 0.5834063
# Epoch: 069, LR: 0.000118, Loss: 0.5489939, Validation loss: 0.6179691, Test loss: 0.5834063
# Epoch: 070, LR: 0.000118, Loss: 0.5485131, Validation loss: 0.6226223, Test loss: 0.5834063
# Epoch: 071, LR: 0.000118, Loss: 0.5488265, Validation loss: 0.6085133, Test loss: 0.5834063
# Epoch: 072, LR: 0.000118, Loss: 0.5499324, Validation loss: 0.6081116, Test loss: 0.5834063
# Epoch: 073, LR: 0.000118, Loss: 0.5461488, Validation loss: 0.6092498, Test loss: 0.5834063
# Epoch: 074, LR: 0.000082, Loss: 0.5460099, Validation loss: 0.6049490, Test loss: 0.5834063
# Epoch: 075, LR: 0.000082, Loss: 0.5449093, Validation loss: 0.6050048, Test loss: 0.5834063
# Epoch: 076, LR: 0.000082, Loss: 0.5447414, Validation loss: 0.6040513, Test loss: 0.5834063
# Epoch: 077, LR: 0.000082, Loss: 0.5444364, Validation loss: 0.6106123, Test loss: 0.5834063
# Epoch: 078, LR: 0.000082, Loss: 0.5466806, Validation loss: 0.6142501, Test loss: 0.5834063
# Epoch: 079, LR: 0.000082, Loss: 0.5442544, Validation loss: 0.6112840, Test loss: 0.5834063
# Epoch: 080, LR: 0.000058, Loss: 0.5425512, Validation loss: 0.6077592, Test loss: 0.5834063
# Epoch: 081, LR: 0.000058, Loss: 0.5433736, Validation loss: 0.6194910, Test loss: 0.5834063
# Epoch: 082, LR: 0.000058, Loss: 0.5444038, Validation loss: 0.6118282, Test loss: 0.5834063
# Epoch: 083, LR: 0.000058, Loss: 0.5429624, Validation loss: 0.6027730, Test loss: 0.5834063
# Epoch: 084, LR: 0.000058, Loss: 0.5434875, Validation loss: 0.6119188, Test loss: 0.5834063
# Epoch: 085, LR: 0.000058, Loss: 0.5428301, Validation loss: 0.6052882, Test loss: 0.5834063
# Epoch: 086, LR: 0.000040, Loss: 0.5417116, Validation loss: 0.6088727, Test loss: 0.5834063
# Epoch: 087, LR: 0.000040, Loss: 0.5412998, Validation loss: 0.6103537, Test loss: 0.5834063
# Epoch: 088, LR: 0.000040, Loss: 0.5412596, Validation loss: 0.6067588, Test loss: 0.5834063
# Epoch: 089, LR: 0.000040, Loss: 0.5409762, Validation loss: 0.6067778, Test loss: 0.5834063
# Epoch: 090, LR: 0.000040, Loss: 0.5404298, Validation loss: 0.6136899, Test loss: 0.5834063
# Epoch: 091, LR: 0.000040, Loss: 0.5412530, Validation loss: 0.6075859, Test loss: 0.5834063
# Epoch: 092, LR: 0.000028, Loss: 0.5398165, Validation loss: 0.6100623, Test loss: 0.5834063
# Epoch: 093, LR: 0.000028, Loss: 0.5397388, Validation loss: 0.6069854, Test loss: 0.5834063
# Epoch: 094, LR: 0.000028, Loss: 0.5392177, Validation loss: 0.6080330, Test loss: 0.5834063
# Epoch: 095, LR: 0.000028, Loss: 0.5392952, Validation loss: 0.6098166, Test loss: 0.5834063
# Epoch: 096, LR: 0.000028, Loss: 0.5397475, Validation loss: 0.6095833, Test loss: 0.5834063
# Epoch: 097, LR: 0.000028, Loss: 0.5402058, Validation loss: 0.6048998, Test loss: 0.5834063
# Epoch: 098, LR: 0.000020, Loss: 0.5393537, Validation loss: 0.6097756, Test loss: 0.5834063
# Epoch: 099, LR: 0.000020, Loss: 0.5388609, Validation loss: 0.6071005, Test loss: 0.5834063
# Epoch: 100, LR: 0.000020, Loss: 0.5391183, Validation loss: 0.6078578, Test loss: 0.5834063
# Epoch: 101, LR: 0.000020, Loss: 0.5388452, Validation loss: 0.6083951, Test loss: 0.5834063
# Epoch: 102, LR: 0.000020, Loss: 0.5387233, Validation loss: 0.6071404, Test loss: 0.5834063
# Epoch: 103, LR: 0.000020, Loss: 0.5384447, Validation loss: 0.6066067, Test loss: 0.5834063
# Epoch: 104, LR: 0.000014, Loss: 0.5379634, Validation loss: 0.6081512, Test loss: 0.5834063
# Epoch: 105, LR: 0.000014, Loss: 0.5379871, Validation loss: 0.6088138, Test loss: 0.5834063
# Epoch: 106, LR: 0.000014, Loss: 0.5383286, Validation loss: 0.6071756, Test loss: 0.5834063
# Epoch: 107, LR: 0.000014, Loss: 0.5384521, Validation loss: 0.6095296, Test loss: 0.5834063
# Epoch: 108, LR: 0.000014, Loss: 0.5379192, Validation loss: 0.6075452, Test loss: 0.5834063
# Epoch: 109, LR: 0.000014, Loss: 0.5377974, Validation loss: 0.6071569, Test loss: 0.5834063
# Epoch: 110, LR: 0.000010, Loss: 0.5382506, Validation loss: 0.6069395, Test loss: 0.5834063
# Epoch: 111, LR: 0.000010, Loss: 0.5388258, Validation loss: 0.6082242, Test loss: 0.5834063
# Epoch: 112, LR: 0.000010, Loss: 0.5374679, Validation loss: 0.6073295, Test loss: 0.5834063
# Epoch: 113, LR: 0.000010, Loss: 0.5374439, Validation loss: 0.6079014, Test loss: 0.5834063
# Epoch: 114, LR: 0.000010, Loss: 0.5373960, Validation loss: 0.6080509, Test loss: 0.5834063
# Epoch: 115, LR: 0.000010, Loss: 0.5373113, Validation loss: 0.6080858, Test loss: 0.5834063
# Epoch: 116, LR: 0.000010, Loss: 0.5373463, Validation loss: 0.6082009, Test loss: 0.5834063
# Epoch: 117, LR: 0.000010, Loss: 0.5373379, Validation loss: 0.6080930, Test loss: 0.5834063
# Epoch: 118, LR: 0.000010, Loss: 0.5372509, Validation loss: 0.6076067, Test loss: 0.5834063
# Epoch: 119, LR: 0.000010, Loss: 0.5373229, Validation loss: 0.6077855, Test loss: 0.5834063
# Epoch: 120, LR: 0.000010, Loss: 0.5370955, Validation loss: 0.6082016, Test loss: 0.5834063
# Epoch: 121, LR: 0.000010, Loss: 0.5371077, Validation loss: 0.6077216, Test loss: 0.5834063
# Epoch: 122, LR: 0.000010, Loss: 0.5371659, Validation loss: 0.6087002, Test loss: 0.5834063
# Epoch: 123, LR: 0.000010, Loss: 0.5372378, Validation loss: 0.6068401, Test loss: 0.5834063
# Epoch: 124, LR: 0.000010, Loss: 0.5373332, Validation loss: 0.6072954, Test loss: 0.5834063
# Epoch: 125, LR: 0.000010, Loss: 0.5371089, Validation loss: 0.6080989, Test loss: 0.5834063
# Epoch: 126, LR: 0.000010, Loss: 0.5369459, Validation loss: 0.6083433, Test loss: 0.5834063
# Epoch: 127, LR: 0.000010, Loss: 0.5368531, Validation loss: 0.6079317, Test loss: 0.5834063
# Epoch: 128, LR: 0.000010, Loss: 0.5370264, Validation loss: 0.6074278, Test loss: 0.5834063
# Epoch: 129, LR: 0.000010, Loss: 0.5369209, Validation loss: 0.6085746, Test loss: 0.5834063
# Epoch: 130, LR: 0.000010, Loss: 0.5368382, Validation loss: 0.6071720, Test loss: 0.5834063
# Epoch: 131, LR: 0.000010, Loss: 0.5367441, Validation loss: 0.6084560, Test loss: 0.5834063
# Epoch: 132, LR: 0.000010, Loss: 0.5367903, Validation loss: 0.6069550, Test loss: 0.5834063
# Epoch: 133, LR: 0.000010, Loss: 0.5370671, Validation loss: 0.6075785, Test loss: 0.5834063
# Epoch: 134, LR: 0.000010, Loss: 0.5365461, Validation loss: 0.6080394, Test loss: 0.5834063
# Epoch: 135, LR: 0.000010, Loss: 0.5366008, Validation loss: 0.6069721, Test loss: 0.5834063
# Epoch: 136, LR: 0.000010, Loss: 0.5364887, Validation loss: 0.6085270, Test loss: 0.5834063
# Epoch: 137, LR: 0.000010, Loss: 0.5365153, Validation loss: 0.6071443, Test loss: 0.5834063
# Epoch: 138, LR: 0.000010, Loss: 0.5364050, Validation loss: 0.6081877, Test loss: 0.5834063
# Epoch: 139, LR: 0.000010, Loss: 0.5362136, Validation loss: 0.6073637, Test loss: 0.5834063
# Epoch: 140, LR: 0.000010, Loss: 0.5366550, Validation loss: 0.6076659, Test loss: 0.5834063
# Epoch: 141, LR: 0.000010, Loss: 0.5362143, Validation loss: 0.6077142, Test loss: 0.5834063
# Epoch: 142, LR: 0.000010, Loss: 0.5360991, Validation loss: 0.6074825, Test loss: 0.5834063
# Epoch: 143, LR: 0.000010, Loss: 0.5361879, Validation loss: 0.6077357, Test loss: 0.5834063
# Epoch: 144, LR: 0.000010, Loss: 0.5360001, Validation loss: 0.6082437, Test loss: 0.5834063
# Epoch: 145, LR: 0.000010, Loss: 0.5361152, Validation loss: 0.6074624, Test loss: 0.5834063
# Epoch: 146, LR: 0.000010, Loss: 0.5360073, Validation loss: 0.6076785, Test loss: 0.5834063
# Epoch: 147, LR: 0.000010, Loss: 0.5360581, Validation loss: 0.6076225, Test loss: 0.5834063
# Epoch: 148, LR: 0.000010, Loss: 0.5361235, Validation loss: 0.6082660, Test loss: 0.5834063
# Epoch: 149, LR: 0.000010, Loss: 0.5358937, Validation loss: 0.6077031, Test loss: 0.5834063
# Epoch: 150, LR: 0.000010, Loss: 0.5357999, Validation loss: 0.6074778, Test loss: 0.5834063
# Epoch: 151, LR: 0.000010, Loss: 0.5357389, Validation loss: 0.6082285, Test loss: 0.5834063
# Epoch: 152, LR: 0.000010, Loss: 0.5358254, Validation loss: 0.6067106, Test loss: 0.5834063
# Epoch: 153, LR: 0.000010, Loss: 0.5359439, Validation loss: 0.6070382, Test loss: 0.5834063
# Epoch: 154, LR: 0.000010, Loss: 0.5356345, Validation loss: 0.6085954, Test loss: 0.5834063
# Epoch: 155, LR: 0.000010, Loss: 0.5358063, Validation loss: 0.6084200, Test loss: 0.5834063
# Epoch: 156, LR: 0.000010, Loss: 0.5356516, Validation loss: 0.6070929, Test loss: 0.5834063
# Epoch: 157, LR: 0.000010, Loss: 0.5356497, Validation loss: 0.6081320, Test loss: 0.5834063
# Epoch: 158, LR: 0.000010, Loss: 0.5355719, Validation loss: 0.6080958, Test loss: 0.5834063
# Epoch: 159, LR: 0.000010, Loss: 0.5353772, Validation loss: 0.6078219, Test loss: 0.5834063
# Epoch: 160, LR: 0.000010, Loss: 0.5355524, Validation loss: 0.6084197, Test loss: 0.5834063
# Epoch: 161, LR: 0.000010, Loss: 0.5354734, Validation loss: 0.6077356, Test loss: 0.5834063
# Epoch: 162, LR: 0.000010, Loss: 0.5354105, Validation loss: 0.6074244, Test loss: 0.5834063
# Epoch: 163, LR: 0.000010, Loss: 0.5356763, Validation loss: 0.6087901, Test loss: 0.5834063
# Epoch: 164, LR: 0.000010, Loss: 0.5352355, Validation loss: 0.6072351, Test loss: 0.5834063
# Epoch: 165, LR: 0.000010, Loss: 0.5356614, Validation loss: 0.6088801, Test loss: 0.5834063
# Epoch: 166, LR: 0.000010, Loss: 0.5363840, Validation loss: 0.6068671, Test loss: 0.5834063
# Epoch: 167, LR: 0.000010, Loss: 0.5355128, Validation loss: 0.6098775, Test loss: 0.5834063
# Epoch: 168, LR: 0.000010, Loss: 0.5351686, Validation loss: 0.6071989, Test loss: 0.5834063
# Epoch: 169, LR: 0.000010, Loss: 0.5351784, Validation loss: 0.6073591, Test loss: 0.5834063
# Epoch: 170, LR: 0.000010, Loss: 0.5351899, Validation loss: 0.6083286, Test loss: 0.5834063
# Epoch: 171, LR: 0.000010, Loss: 0.5349845, Validation loss: 0.6076968, Test loss: 0.5834063
# Epoch: 172, LR: 0.000010, Loss: 0.5351691, Validation loss: 0.6069937, Test loss: 0.5834063
# Epoch: 173, LR: 0.000010, Loss: 0.5352583, Validation loss: 0.6068749, Test loss: 0.5834063
# Epoch: 174, LR: 0.000010, Loss: 0.5351171, Validation loss: 0.6072433, Test loss: 0.5834063
# Epoch: 175, LR: 0.000010, Loss: 0.5350839, Validation loss: 0.6093394, Test loss: 0.5834063
# Epoch: 176, LR: 0.000010, Loss: 0.5348403, Validation loss: 0.6065761, Test loss: 0.5834063
# Epoch: 177, LR: 0.000010, Loss: 0.5349198, Validation loss: 0.6080634, Test loss: 0.5834063
# Epoch: 178, LR: 0.000010, Loss: 0.5348616, Validation loss: 0.6077804, Test loss: 0.5834063
# Epoch: 179, LR: 0.000010, Loss: 0.5347278, Validation loss: 0.6072466, Test loss: 0.5834063
# Epoch: 180, LR: 0.000010, Loss: 0.5346956, Validation loss: 0.6076269, Test loss: 0.5834063
# Epoch: 181, LR: 0.000010, Loss: 0.5345190, Validation loss: 0.6085442, Test loss: 0.5834063
# Epoch: 182, LR: 0.000010, Loss: 0.5348025, Validation loss: 0.6080941, Test loss: 0.5834063
# Epoch: 183, LR: 0.000010, Loss: 0.5347924, Validation loss: 0.6074195, Test loss: 0.5834063
# Epoch: 184, LR: 0.000010, Loss: 0.5346662, Validation loss: 0.6078594, Test loss: 0.5834063
# Epoch: 185, LR: 0.000010, Loss: 0.5344531, Validation loss: 0.6075853, Test loss: 0.5834063
# Epoch: 186, LR: 0.000010, Loss: 0.5344726, Validation loss: 0.6077803, Test loss: 0.5834063
# Epoch: 187, LR: 0.000010, Loss: 0.5345414, Validation loss: 0.6089642, Test loss: 0.5834063
# Epoch: 188, LR: 0.000010, Loss: 0.5344608, Validation loss: 0.6078792, Test loss: 0.5834063
# Epoch: 189, LR: 0.000010, Loss: 0.5343233, Validation loss: 0.6083850, Test loss: 0.5834063
# Epoch: 190, LR: 0.000010, Loss: 0.5343285, Validation loss: 0.6081130, Test loss: 0.5834063
# Epoch: 191, LR: 0.000010, Loss: 0.5344499, Validation loss: 0.6073192, Test loss: 0.5834063
# Epoch: 192, LR: 0.000010, Loss: 0.5344175, Validation loss: 0.6073699, Test loss: 0.5834063
# Epoch: 193, LR: 0.000010, Loss: 0.5342071, Validation loss: 0.6094468, Test loss: 0.5834063
# Epoch: 194, LR: 0.000010, Loss: 0.5342867, Validation loss: 0.6075552, Test loss: 0.5834063
# Epoch: 195, LR: 0.000010, Loss: 0.5341318, Validation loss: 0.6082381, Test loss: 0.5834063
# Epoch: 196, LR: 0.000010, Loss: 0.5341754, Validation loss: 0.6083572, Test loss: 0.5834063
# Epoch: 197, LR: 0.000010, Loss: 0.5341006, Validation loss: 0.6093831, Test loss: 0.5834063
# Epoch: 198, LR: 0.000010, Loss: 0.5339328, Validation loss: 0.6079519, Test loss: 0.5834063
# Epoch: 199, LR: 0.000010, Loss: 0.5342247, Validation loss: 0.6084402, Test loss: 0.5834063

# %%
#グラフ化
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.plot(Epoch_list, Loss_list, label = 'Loss')
plt.plot(Epoch_list, Val_list, label = 'Validation loss')
plt.plot(Epoch_list, Test_list, label = 'Test loss')

# 凡例を表示
plt.legend(loc=5)

# 軸ラベル
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.show()
