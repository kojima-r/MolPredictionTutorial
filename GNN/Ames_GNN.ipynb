# %%
### Pytorch geometry (グラフニューラルネットワークライブラリ) のインストール(only first time)
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
# ライブラリ確認
import numpy as np
import pandas as pd
import rdkit
from rdkit import Chem
import torch
from torch_geometric.data import Data as TorchGeometricData

print(Chem.__doc__)
# Out:
#  A module for molecules and stuff
#
#  see Chem/index.html in the doc tree for documentation

# %%
#wavefunctionファイルの読み込み
import glob
import re
files = []
for file in glob.glob("../WaveFunctions/Ames_test/*_Ames_wavefunction.npy"):
    files.append(file)

data_num = len(files)
print("start with {} wavefunctions".format(data_num))
# Out:
# start with 100 wavefunctions

# %%
#wavefunctionの取り出し
import psi4

#スレッド数とメモリの設定
psi4.set_num_threads(nthread=5)
psi4.set_memory("10GB")

ID_list = []
wavefunction_list = []
for file in files:
    pre_ID = re.findall('../WaveFunctions/Ames_test/(.*)_Ames_wavefunction.npy', file)
    ID = pre_ID[0]
    ID_list.append(int(ID))
    wave_function = psi4.core.Wavefunction.from_file(file)
    wavefunction_list.append(wave_function)
# Out:
#   Threads set to 5 by Python driver.
#
#   Memory set to   9.313 GiB by Python driver.
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5    entry I          line  1083 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-8  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 23-24 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-21     entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-35    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-11  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-14 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-23 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-29   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-7, 9-10, 12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 11         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-22         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-4 entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 10    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 11    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-27    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 14     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-30     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 8, 10, 12-18 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 9, 11          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-40             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-14  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-28 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6 entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-5  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-14 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6-9, 11-17, 19-24, 31-32 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2                           entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-4                         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 10, 18, 25-30            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 33-47                       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5, 8-17, 19-25, 27-28 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-7, 18, 26             entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 29-68                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6, 14            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 8-13, 15-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4                   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7                   entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-34               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-9, 11-22 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-37      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 11   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-19      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-8, 10, 13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2              entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 11-12       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-24          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 10    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-22    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8, 10-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-25      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 6, 8-12, 14-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-4, 7              entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5                   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13                  entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-36               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-6 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 7     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-15     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6-7, 9-10, 12-13, 15-17, 19-20, 22-23, 25-26, 28-38 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 8, 11, 14, 18, 21, 24, 27                             entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 39-54                                                    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-8, 12, 15-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 10-11, 13      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 14             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-32             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-14 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-18 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-30     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 8, 12-13, 15 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 7, 9, 11, 14   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6                    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10                   entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-23                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-11  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-35 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 6-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 5      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-9, 12-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-11      entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-16      entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-20      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-7  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 16                                 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4, 6-12, 14-15, 17-22, 26-27, 33-34 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 13, 24-25, 28, 30-32, 36-38        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23, 29, 35                            entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 39-56                                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-7   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-17 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-5, 7-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 18            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-7, 9-10, 12-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 11            entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-34            entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-21  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-33 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 9-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 7-8    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6         entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-31     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1    entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-7  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-12 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 10, 21, 29, 36, 44                                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-9, 11-16, 18-20, 22-28, 30-31, 33-35, 37-43, 45-50 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17, 32                                               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 51-68                                                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 6                 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 7-8, 10-12, 14-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 13, 16-17            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9                       entry I          line  1083 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-29                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 6, 14  entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 7-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-18        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-16 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 7-8, 11-12, 14-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4                      entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-6, 13, 18-19         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10, 17               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-32                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-10  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-11  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-26 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-10  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11    entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-17 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-5, 7-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 12-13    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6, 10-11    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-22       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-13  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-22 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-19  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-22 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-35 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 6                  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 7-9, 11-12, 14, 16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 10, 13, 15, 17        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-30                    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-8, 10-11, 13-15, 17-18, 20-21, 23-24, 26-27, 29 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 9, 12, 16, 19, 22, 25, 28, 30                     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 31-48                                                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 9-10    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-8, 11-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-26      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 10      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-8, 12-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9          entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11         entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-16      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 6-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-31      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-26   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 10           entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-9, 11-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-23           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-9, 11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-18  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-28 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-18  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5-6, 10, 12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 7-8, 11     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9                 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-19             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5, 8, 10                 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 6-7, 9, 11, 13-14, 16-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12, 15, 18                     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-31                          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-8, 10-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4               entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9               entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-22 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-39   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2        entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 5-10  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-18    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 12                             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-5, 7-8, 10-11, 13-15, 17-18, 20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6, 9, 16, 19                      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-30                             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 7-11, 13-20, 22-28 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 21, 29               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6, 30-31                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12                      entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 32-51                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 6-7, 12-13       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 8-9, 11, 14-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10, 16                 entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-28                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-19  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-31 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-5, 7, 9, 12, 14, 16-22, 25-28, 31 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 6, 8, 10-11, 13, 15, 24             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23, 29-30, 32-33                       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 34-55                                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 8-13, 15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-26         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4, 6-8, 13-18, 20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 5, 12               entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-11, 19               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-32                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 6   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-12   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-20     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 11-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 14      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6, 8-10    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7          entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-24      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 21       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-10, 12-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11          entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-34       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8, 10-18, 20-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 19, 22         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-43             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 10    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-28    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-7   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-9   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-16 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6        entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-11     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6-7, 9, 11-14, 16-17, 19, 21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 8, 10, 15, 18, 20, 22          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-42                             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-10  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-25 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-7, 9-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 8         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-35        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-6, 8-10, 12-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 7, 11            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-27               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 9     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 10-11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-17    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1       entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-9, 11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-17   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-8, 11-19 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-34      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-5, 7-18 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 6, 19     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-40        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 6-11, 13-18, 20, 22-29, 31-32, 34-35, 38-39 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 12, 19, 21, 30, 37                            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 33, 36                                              entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 40-72                                               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-7 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4        entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-22     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 6, 8, 10, 12 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 7, 9, 11   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-26              entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3        entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-20    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5, 7, 9-16, 18-20, 23-24, 26-30 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6, 8, 21-22, 25                     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17, 31                                 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 32-61                                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-14 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-8, 10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 11      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9          entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-21      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 10 entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-9   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-18 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5, 7-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-23    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-6, 8, 10-12, 14-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 7, 17-18               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9                         entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13                        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-35                     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-10   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-7, 9-10, 13, 16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 15                  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 11-12, 14, 17       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-31                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-33   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs

# %%
#データのリスト化とソート
data_sets = pd.DataFrame({'ID': ID_list, 'wavefunction': wavefunction_list})
data_sets = data_sets.sort_values('ID')
sort_data_sets = data_sets.reset_index(drop=True)

# %%
#元データの読み込み
original_df = pd.read_csv( '../AmesCalculation/AvailableAmesDataSets.csv')
print('original data has {} molecules'.format(len(original_df.index))) #6506
# Out:
# original data has 6506 molecules

# %%
#smiles & activityの取得
smiles_list = []
act_list = []
for ID in sort_data_sets.ID :
    same_df = original_df.query('ID == @ID')
    smile = same_df['smiles'].values[0]
    act = same_df['activity'].values[0]
    smiles_list.append(smile)
    act_list.append(float(act))
    
sort_data_sets['smiles'] = smiles_list
sort_data_sets['activity'] = act_list

# %%
#activityのカウント
pd.value_counts(sort_data_sets.activity)
# Out:
# 1.0    52
# 0.0    48
# Name: activity, dtype: int64

# %%
#detaの分割
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(sort_data_sets, random_state=0)
train, val = train_test_split(train_val)

# %%
## pandasのデータフレームからRDkitのmolオブジェクトXとラベルYのペアに変換

Xwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Ywf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Zwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
for (smile, act, wf) in zip(train.smiles, train.activity, train.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol)  
    Xwf["train"].append(mol)
    Ywf["train"].append(act)
    Zwf["train"].append(wf)
for (smile, act, wf) in zip(val.smiles, val.activity, val.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol) 
    Xwf["valid"].append(mol)
    Ywf["valid"].append(act)
    Zwf["valid"].append(wf)
for (smile, act, wf) in zip(test.smiles, test.activity, test.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol) 
    Xwf["test"].append(mol)
    Ywf["test"].append(act)
    Zwf["test"].append(wf)

# %%
def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception(
            "input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))


def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def get_atom_features(atom, en_list=None, explicit_H=False, use_sybyl=False, use_electronegativity=False,
                  use_gasteiger=False, degree_dim=17):
    if use_sybyl:
        atom_type = ordkit._sybyl_atom_type(atom)
        atom_list = ['C.ar', 'C.cat', 'C.1', 'C.2', 'C.3', 'N.ar', 'N.am', 'N.pl3', 'N.1', 'N.2', 'N.3', 'N.4', 'O.co2',
                     'O.2', 'O.3', 'S.O', 'S.o2', 'S.2', 'S.3', 'F', 'Si', 'P', 'P3', 'Cl', 'Br', 'Mg', 'Na', 'Ca',
                     'Fe', 'As', 'Al', 'I', 'B', 'V', 'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn',
                     'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni', 'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    else:
        atom_type = atom.GetSymbol()
        atom_list = ['C', 'N', 'O', 'S', 'F', 'Si', 'P', 'Cl', 'Br', 'Mg', 'Na', 'Ca', 'Fe', 'As', 'Al', 'I', 'B', 'V',
                     'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn', 'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni',
                     'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    results = one_of_k_encoding_unk(atom_type, atom_list) + \
        one_of_k_encoding(atom.GetDegree(), list(range(degree_dim))) + \
        one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3, 4, 5, 6]) + \
        [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + \
        one_of_k_encoding_unk(atom.GetHybridization(),
                              [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
                               Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.SP3D,
                               Chem.rdchem.HybridizationType.SP3D2]) + \
        [atom.GetIsAromatic()]

    if use_electronegativity:
        results = results + [en_list[atom.GetAtomicNum() - 1]]
    if use_gasteiger:
        gasteiger = atom.GetDoubleProp('_GasteigerCharge')
        if np.isnan(gasteiger) or np.isinf(gasteiger):
            gasteiger = 0  # because the mean is 0
        results = results + [gasteiger]

    # In case of explicit hydrogen(QM8, QM9), avoid calling `GetTotalNumHs`
    if not explicit_H:
        results = results + one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3, 4])
    return np.array(results, dtype=np.float32)

def get_bond_features(bond):
  results=one_of_k_encoding_unk(bond.GetBondType(),[Chem.rdchem.BondType.SINGLE,
                         Chem.rdchem.BondType.DOUBLE,
                         Chem.rdchem.BondType.TRIPLE,
                         Chem.rdchem.BondType.AROMATIC])
  return np.array(results, dtype=np.float32)

# %%
import torch
from rdkit import Chem
from torch_geometric.data import Data as TorchGeometricData
from torch_geometric.data import DataLoader

def get_edge_features(mol):
    edge_list= []
    num_bond_features=0
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        bond_features = get_bond_features(bond)
        num_bond_features=len(bond_features)
        edge_list += [([i, j],bond_features), ([j, i],bond_features)]
    return edge_list, num_bond_features

#modified mol2geodata
#規格化関数
def rescaling(features):
    norm_features = []
    max_value = max(features)
    min_value = min(features)
    for feature in features:
        norm_feature = (feature - min_value)/(max_value - min_value)
        norm_features.append(norm_feature)
    
    return norm_features

def get_WF_results(wf):
    #Mulliken電荷
    psi4.oeprop(wf, "MULLIKEN_CHARGES")
    M_charges = np.array(wf.atomic_point_charges())
    norm_M_charges = rescaling(M_charges)
    #Löwdin電荷
    psi4.oeprop(wf, "LOWDIN_CHARGES")
    L_charges = np.array(wf.atomic_point_charges())
    norm_L_charges = rescaling(L_charges)
    #wf_molecule
    wf_mol = wf.molecule()
    wf_atom_num = wf_mol.natom()
    x_dem_list = []
    y_dem_list = []
    z_dem_list = []
    for num in list(range(wf_atom_num)):
        xyz = wf_mol.xyz(num)
        #x
        if xyz[0] < 0:
            x_dem_list.append(0)
        else:
            x_dem_list.append(1)
        #y
        if xyz[1] < 0:
            y_dem_list.append(0)
        else:
            y_dem_list.append(1)
        #z
        if xyz[2] < 0:
            z_dem_list.append(0)
        else:
            z_dem_list.append(1)
    x_dems = np.array(x_dem_list)
    y_dems = np.array(y_dem_list)
    z_dems = np.array(z_dem_list)
    #energy
    #energy = wf.energy()
    #homo/lumo
    LUMO_idx = wf.nalpha()
    HOMO_idx = LUMO_idx - 1
    homo = wf.epsilon_a_subset("AO", "ALL").np[HOMO_idx]
    lumo = wf.epsilon_a_subset("AO", "ALL").np[LUMO_idx]
    #結果のまとめ                           
    WF_results = [np.array([Mcharge,Lcharge,x_dem,y_dem,z_dem,homo,lumo], dtype=np.float32) for (Mcharge,Lcharge,x_dem,y_dem,z_dem) in zip(norm_M_charges, norm_L_charges,x_dems,y_dems,z_dems)]
    
    return WF_results

def mol2geodataWF(mol,y,z):
    smile = Chem.MolToSmiles(mol)
    atom_features =[get_atom_features(atom) for atom in mol.GetAtoms()]
    WF_results = get_WF_results(z)
    atom_features = np.append(atom_features, WF_results, axis=1)
    num_atom_features=len(atom_features[0])
    atom_features = torch.FloatTensor(atom_features).view(-1, len(atom_features[0]))

    edge_list,num_bond_features = get_edge_features(mol)
    edge_list=sorted(edge_list)
    
    edge_indices=[e for e,v in edge_list]
    edge_attributes=[v for e,v in edge_list]
    edge_indices = torch.tensor(edge_indices)
    edge_indices = edge_indices.t().to(torch.long).view(2, -1)
    edge_attributes = torch.FloatTensor(edge_attributes)
    #print(num_atom_features,num_bond_features)
    return TorchGeometricData(x=atom_features, edge_index=edge_indices, edge_attr=edge_attributes, num_atom_features=num_atom_features,num_bond_features=num_bond_features,smiles=smile, y=y)

# %%
train_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["train"],Ywf["train"],Zwf["train"])]
train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)

valid_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["valid"],Ywf["valid"],Zwf["valid"])]
valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)

test_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["test"],Ywf["test"],Zwf["test"])]
test_loader = DataLoader(test_data_list, batch_size=128,shuffle=True)
# Out:
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.08979  3.08979  0.00000 -0.17959
#        2     C     3.05145  3.05145  0.00000 -0.10290
#        3     C     2.94744  2.94744  0.00000  0.10511
#        4     C     3.09331  3.09331  0.00000 -0.18662
#        5     C     3.02885  3.02885  0.00000 -0.05769
#        6     O     4.11278  4.11278  0.00000 -0.22556
#        7     H     0.47100  0.47100  0.00000  0.05800
#        8     H     0.46939  0.46939  0.00000  0.06123
#        9     H     0.46475  0.46475  0.00000  0.07050
#       10     H     0.46969  0.46969  0.00000  0.06062
#       11     H     0.47035  0.47035  0.00000  0.05930
#       12     H     0.46544  0.46544  0.00000  0.06913
#       13     H     0.46658  0.46658  0.00000  0.06685
#       14     H     0.46728  0.46728  0.00000  0.06544
#       15     H     0.46644  0.46644  0.00000  0.06713
#       16     H     0.46548  0.46548  0.00000  0.06904
#
#    Total alpha = 24.00000, Total beta = 24.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04438  3.04438  0.00000 -0.08875
#        2     C     3.02136  3.02136  0.00000 -0.04271
#        3     C     2.95076  2.95076  0.00000  0.09849
#        4     C     3.04982  3.04982  0.00000 -0.09965
#        5     C     3.00537  3.00537  0.00000 -0.01073
#        6     O     4.08904  4.08904  0.00000 -0.17808
#        7     H     0.48598  0.48598  0.00000  0.02804
#        8     H     0.48469  0.48469  0.00000  0.03061
#        9     H     0.48130  0.48130  0.00000  0.03740
#       10     H     0.48594  0.48594  0.00000  0.02812
#       11     H     0.48627  0.48627  0.00000  0.02745
#       12     H     0.48141  0.48141  0.00000  0.03718
#       13     H     0.48243  0.48243  0.00000  0.03515
#       14     H     0.48275  0.48275  0.00000  0.03451
#       15     H     0.48472  0.48472  0.00000  0.03056
#       16     H     0.48379  0.48379  0.00000  0.03242
#
#   Total alpha = 24.00000, Total beta = 24.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.08999  3.08999  0.00000 -0.17999
#        2     C     3.04910  3.04910  0.00000 -0.09819
#        3     C     2.96315  2.96315  0.00000  0.07370
#        4     O     4.14538  4.14538  0.00000 -0.29075
#        5     C     3.03623  3.03623  0.00000 -0.07246
#        6     C     3.03565  3.03565  0.00000 -0.07130
#        7     C     3.02758  3.02758  0.00000 -0.05517
#        8     C     3.03160  3.03160  0.00000 -0.06319
#        9     C     3.02539  3.02539  0.00000 -0.05078
#       10     C     3.03231  3.03231  0.00000 -0.06463
#       11     C     3.02024  3.02024  0.00000 -0.04048
#       12     C     3.04614  3.04614  0.00000 -0.09227
#       13     C     2.93378  2.93378  0.00000  0.13245
#       14     O     4.10606  4.10606  0.00000 -0.21211
#       15     H     0.47128  0.47128  0.00000  0.05744
#       16     H     0.46884  0.46884  0.00000  0.06231
#       17     H     0.47033  0.47033  0.00000  0.05933
#       18     H     0.46890  0.46890  0.00000  0.06220
#       19     H     0.46823  0.46823  0.00000  0.06354
#       20     H     0.47734  0.47734  0.00000  0.04532
#       21     H     0.41411  0.41411  0.00000  0.17179
#       22     H     0.47072  0.47072  0.00000  0.05855
#       23     H     0.46600  0.46600  0.00000  0.06799
#       24     H     0.46960  0.46960  0.00000  0.06080
#       25     H     0.46893  0.46893  0.00000  0.06215
#       26     H     0.46786  0.46786  0.00000  0.06427
#       27     H     0.46870  0.46870  0.00000  0.06260
#       28     H     0.46173  0.46173  0.00000  0.07653
#       29     H     0.46880  0.46880  0.00000  0.06241
#       30     H     0.47603  0.47603  0.00000  0.04793
#
#    Total alpha = 52.00000, Total beta = 52.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04473  3.04473  0.00000 -0.08946
#        2     C     3.01788  3.01788  0.00000 -0.03575
#        3     C     2.95468  2.95468  0.00000  0.09065
#        4     O     4.10566  4.10566  0.00000 -0.21131
#        5     C     3.02277  3.02277  0.00000 -0.04555
#        6     C     3.01988  3.01988  0.00000 -0.03976
#        7     C     3.01114  3.01114  0.00000 -0.02228
#        8     C     3.01662  3.01662  0.00000 -0.03324
#        9     C     3.00820  3.00820  0.00000 -0.01640
#       10     C     3.01784  3.01784  0.00000 -0.03569
#       11     C     2.99999  2.99999  0.00000  0.00002
#       12     C     3.03650  3.03650  0.00000 -0.07300
#       13     C     2.94218  2.94218  0.00000  0.11564
#       14     O     4.07332  4.07332  0.00000 -0.14665
#       15     H     0.48635  0.48635  0.00000  0.02730
#       16     H     0.48432  0.48432  0.00000  0.03137
#       17     H     0.48559  0.48559  0.00000  0.02882
#       18     H     0.48548  0.48548  0.00000  0.02904
#       19     H     0.48490  0.48490  0.00000  0.03019
#       20     H     0.49469  0.49469  0.00000  0.01061
#       21     H     0.44028  0.44028  0.00000  0.11943
#       22     H     0.48609  0.48609  0.00000  0.02782
#       23     H     0.48249  0.48249  0.00000  0.03502
#       24     H     0.48533  0.48533  0.00000  0.02935
#       25     H     0.48476  0.48476  0.00000  0.03048
#       26     H     0.48399  0.48399  0.00000  0.03203
#       27     H     0.48462  0.48462  0.00000  0.03076
#       28     H     0.47941  0.47941  0.00000  0.04118
#       29     H     0.48452  0.48452  0.00000  0.03095
#       30     H     0.49579  0.49579  0.00000  0.00841
#
#   Total alpha = 52.00000, Total beta = 52.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.10348  3.10348  0.00000 -0.20696
#        2     C     2.83835  2.83835  0.00000  0.32330
#        3     O     4.11644  4.11644  0.00000 -0.23287
#        4     O     4.09168  4.09168  0.00000 -0.18336
#        5     N     3.59190  3.59190  0.00000 -0.18379
#        6     C     2.84959  2.84959  0.00000  0.30082
#        7     O     4.12088  4.12088  0.00000 -0.24177
#        8     C     3.10219  3.10219  0.00000 -0.20438
#        9     C     2.95450  2.95450  0.00000  0.09100
#       10     C     3.03714  3.03714  0.00000 -0.07429
#       11     C     3.03226  3.03226  0.00000 -0.06452
#       12     C     3.04765  3.04765  0.00000 -0.09530
#       13     S     7.90336  7.90336  0.00000  0.19329
#       14     C     3.04553  3.04553  0.00000 -0.09105
#       15     C     3.03553  3.03553  0.00000 -0.07107
#       16     C     3.02985  3.02985  0.00000 -0.05970
#       17     C     3.03347  3.03347  0.00000 -0.06693
#       18     C     3.03007  3.03007  0.00000 -0.06014
#       19     C     3.03452  3.03452  0.00000 -0.06905
#       20     C     3.03080  3.03080  0.00000 -0.06159
#       21     C     3.02966  3.02966  0.00000 -0.05933
#       22     H     0.45707  0.45707  0.00000  0.08586
#       23     H     0.45764  0.45764  0.00000  0.08472
#       24     H     0.45620  0.45620  0.00000  0.08760
#       25     H     0.45799  0.45799  0.00000  0.08403
#       26     H     0.45793  0.45793  0.00000  0.08414
#       27     H     0.45908  0.45908  0.00000  0.08183
#       28     H     0.46329  0.46329  0.00000  0.07341
#       29     H     0.46673  0.46673  0.00000  0.06655
#       30     H     0.46735  0.46735  0.00000  0.06529
#       31     H     0.46766  0.46766  0.00000  0.06468
#       32     H     0.46832  0.46832  0.00000  0.06335
#       33     H     0.46775  0.46775  0.00000  0.06451
#       34     H     0.46836  0.46836  0.00000  0.06327
#       35     H     0.46593  0.46593  0.00000  0.06814
#       36     H     0.45985  0.45985  0.00000  0.08029
#
#    Total alpha = 79.00000, Total beta = 79.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.05862  3.05862  0.00000 -0.11725
#        2     C     2.88009  2.88009  0.00000  0.23982
#        3     O     4.08663  4.08663  0.00000 -0.17327
#        4     O     4.06805  4.06805  0.00000 -0.13611
#        5     N     3.55915  3.55915  0.00000 -0.11830
#        6     C     2.88838  2.88838  0.00000  0.22325
#        7     O     4.09204  4.09204  0.00000 -0.18407
#        8     C     3.05787  3.05787  0.00000 -0.11575
#        9     C     2.96455  2.96455  0.00000  0.07090
#       10     C     3.02495  3.02495  0.00000 -0.04989
#       11     C     3.01869  3.01869  0.00000 -0.03738
#       12     C     3.04562  3.04562  0.00000 -0.09124
#       13     S     7.89629  7.89629  0.00000  0.20742
#       14     C     3.04233  3.04233  0.00000 -0.08466
#       15     C     3.02253  3.02253  0.00000 -0.04506
#       16     C     3.01340  3.01340  0.00000 -0.02680
#       17     C     3.01808  3.01808  0.00000 -0.03616
#       18     C     3.01353  3.01353  0.00000 -0.02706
#       19     C     3.02169  3.02169  0.00000 -0.04338
#       20     C     3.01706  3.01706  0.00000 -0.03412
#       21     C     3.01698  3.01698  0.00000 -0.03395
#       22     H     0.47427  0.47427  0.00000  0.05146
#       23     H     0.47474  0.47474  0.00000  0.05052
#       24     H     0.47396  0.47396  0.00000  0.05209
#       25     H     0.47504  0.47504  0.00000  0.04992
#       26     H     0.47538  0.47538  0.00000  0.04925
#       27     H     0.47588  0.47588  0.00000  0.04823
#       28     H     0.48029  0.48029  0.00000  0.03943
#       29     H     0.48315  0.48315  0.00000  0.03369
#       30     H     0.48364  0.48364  0.00000  0.03273
#       31     H     0.48393  0.48393  0.00000  0.03214
#       32     H     0.48440  0.48440  0.00000  0.03120
#       33     H     0.48398  0.48398  0.00000  0.03204
#       34     H     0.48454  0.48454  0.00000  0.03092
#       35     H     0.48265  0.48265  0.00000  0.03471
#       36     H     0.47762  0.47762  0.00000  0.04476
#
#   Total alpha = 79.00000, Total beta = 79.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.03700  3.03700  0.00000 -0.07400
#        2     N     3.66353  3.66353  0.00000 -0.32706
#        3     C     2.81216  2.81216  0.00000  0.37568
#        4     O     4.11075  4.11075  0.00000 -0.22151
#        5     H     0.46057  0.46057  0.00000  0.07886
#        6     H     0.45542  0.45542  0.00000  0.08917
#        7     H     0.46057  0.46057  0.00000  0.07886
#
#    Total alpha = 15.00000, Total beta = 15.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     2.99616  2.99616  0.00000  0.00768
#        2     N     3.63401  3.63401  0.00000 -0.26803
#        3     C     2.85949  2.85949  0.00000  0.28102
#        4     O     4.07653  4.07653  0.00000 -0.15306
#        5     H     0.47939  0.47939  0.00000  0.04123
#        6     H     0.47503  0.47503  0.00000  0.04993
#        7     H     0.47939  0.47939  0.00000  0.04123
#
#   Total alpha = 15.00000, Total beta = 15.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.08899  3.08899  0.00000 -0.17798
#        2     C     3.04714  3.04714  0.00000 -0.09429
#        3     C     3.04714  3.04714  0.00000 -0.09429
#        4     C     3.08899  3.08899  0.00000 -0.17798
#        5     H     0.47182  0.47182  0.00000  0.05637
#        6     H     0.47124  0.47124  0.00000  0.05752
#        7     H     0.47182  0.47182  0.00000  0.05637
#        8     H     0.47449  0.47449  0.00000  0.05101
#        9     H     0.47449  0.47449  0.00000  0.05101
#       10     H     0.47449  0.47449  0.00000  0.05101
#       11     H     0.47449  0.47449  0.00000  0.05101
#       12     H     0.47124  0.47124  0.00000  0.05752
#       13     H     0.47182  0.47182  0.00000  0.05637
#       14     H     0.47182  0.47182  0.00000  0.05637
#
#    Total alpha = 17.00000, Total beta = 17.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04440  3.04440  0.00000 -0.08880
#        2     C     3.01600  3.01600  0.00000 -0.03200
#        3     C     3.01600  3.01600  0.00000 -0.03200
#        4     C     3.04440  3.04440  0.00000 -0.08880
#        5     H     0.48677  0.48677  0.00000  0.02647
#        6     H     0.48625  0.48625  0.00000  0.02749
#        7     H     0.48677  0.48677  0.00000  0.02647
#        8     H     0.48991  0.48991  0.00000  0.02019
#        9     H     0.48991  0.48991  0.00000  0.02019
#       10     H     0.48991  0.48991  0.00000  0.02019
#       11     H     0.48991  0.48991  0.00000  0.02019
#       12     H     0.48625  0.48625  0.00000  0.02749
#       13     H     0.48677  0.48677  0.00000  0.02647
#       14     H     0.48677  0.48677  0.00000  0.02647
#
#   Total alpha = 17.00000, Total beta = 17.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.09226  3.09226  0.00000 -0.18451
#        2     C     2.99054  2.99054  0.00000  0.01893
#        3     C     3.03043  3.03043  0.00000 -0.06086
#        4     C     3.03049  3.03049  0.00000 -0.06098
#        5     C     2.99599  2.99599  0.00000  0.00801
#        6     C     3.02752  3.02752  0.00000 -0.05504
#        7     C     3.03023  3.03023  0.00000 -0.06047
#        8     C     2.96213  2.96213  0.00000  0.07573
#        9     C     3.02340  3.02340  0.00000 -0.04681
#       10     C     2.99772  2.99772  0.00000  0.00456
#       11     C     3.03312  3.03312  0.00000 -0.06624
#       12     N     3.43595  3.43595  0.00000  0.12810
#       13     O     4.09452  4.09452  0.00000 -0.18905
#       14     O     4.09369  4.09369  0.00000 -0.18739
#       15     H     0.46499  0.46499  0.00000  0.07003
#       16     H     0.46581  0.46581  0.00000  0.06839
#       17     H     0.46499  0.46499  0.00000  0.07003
#       18     H     0.46646  0.46646  0.00000  0.06709
#       19     H     0.46616  0.46616  0.00000  0.06768
#       20     H     0.46339  0.46339  0.00000  0.07322
#       21     H     0.45200  0.45200  0.00000  0.09601
#       22     H     0.45092  0.45092  0.00000  0.09816
#       23     H     0.46730  0.46730  0.00000  0.06541
#
#    Total alpha = 49.00000, Total beta = 49.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04592  3.04592  0.00000 -0.09184
#        2     C     2.98656  2.98656  0.00000  0.02688
#        3     C     3.01479  3.01479  0.00000 -0.02958
#        4     C     3.01599  3.01599  0.00000 -0.03197
#        5     C     2.99297  2.99297  0.00000  0.01406
#        6     C     3.01250  3.01250  0.00000 -0.02499
#        7     C     3.01565  3.01565  0.00000 -0.03130
#        8     C     2.97852  2.97852  0.00000  0.04296
#        9     C     3.00817  3.00817  0.00000 -0.01634
#       10     C     2.99565  2.99565  0.00000  0.00869
#       11     C     3.02129  3.02129  0.00000 -0.04257
#       12     N     3.37852  3.37852  0.00000  0.24297
#       13     O     4.10928  4.10928  0.00000 -0.21856
#       14     O     4.10837  4.10837  0.00000 -0.21675
#       15     H     0.48095  0.48095  0.00000  0.03811
#       16     H     0.48181  0.48181  0.00000  0.03639
#       17     H     0.48094  0.48094  0.00000  0.03811
#       18     H     0.48303  0.48303  0.00000  0.03393
#       19     H     0.48273  0.48273  0.00000  0.03453
#       20     H     0.48060  0.48060  0.00000  0.03881
#       21     H     0.47154  0.47154  0.00000  0.05692
#       22     H     0.47067  0.47067  0.00000  0.05866
#       23     H     0.48356  0.48356  0.00000  0.03289
#
#   Total alpha = 49.00000, Total beta = 49.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.08871  3.08871  0.00000 -0.17741
#        2     C     3.02103  3.02103  0.00000 -0.04205
#        3     C     2.96951  2.96951  0.00000  0.06098
#        4     N     3.64817  3.64817  0.00000 -0.29634
#        5     C     2.91041  2.91041  0.00000  0.17919
#        6     C     3.06537  3.06537  0.00000 -0.13074
#        7     C     2.97255  2.97255  0.00000  0.05489
#        8     O     4.14753  4.14753  0.00000 -0.29506
#        9     C     2.97020  2.97020  0.00000  0.05960
#       10     C     2.99996  2.99996  0.00000  0.00008
#       11     O     4.14617  4.14617  0.00000 -0.29234
#       12     O     4.12621  4.12621  0.00000 -0.25243
#       13     C     2.79509  2.79509  0.00000  0.40983
#       14     O     4.14849  4.14849  0.00000 -0.29698
#       15     N     3.68806  3.68806  0.00000 -0.37612
#       16     C     2.84917  2.84917  0.00000  0.30165
#       17     O     4.13197  4.13197  0.00000 -0.26394
#       18     H     0.46261  0.46261  0.00000  0.07478
#       19     H     0.46301  0.46301  0.00000  0.07399
#       20     H     0.46754  0.46754  0.00000  0.06493
#       21     H     0.45788  0.45788  0.00000  0.08423
#       22     H     0.46663  0.46663  0.00000  0.06675
#       23     H     0.46173  0.46173  0.00000  0.07655
#       24     H     0.46496  0.46496  0.00000  0.07009
#       25     H     0.46462  0.46462  0.00000  0.07077
#       26     H     0.40773  0.40773  0.00000  0.18453
#       27     H     0.47030  0.47030  0.00000  0.05941
#       28     H     0.47181  0.47181  0.00000  0.05638
#       29     H     0.46491  0.46491  0.00000  0.07018
#       30     H     0.40532  0.40532  0.00000  0.18935
#       31     H     0.39237  0.39237  0.00000  0.21527
#
#    Total alpha = 64.00000, Total beta = 64.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04178  3.04178  0.00000 -0.08356
#        2     C     3.03270  3.03270  0.00000 -0.06540
#        3     C     2.96759  2.96759  0.00000  0.06483
#        4     N     3.58868  3.58868  0.00000 -0.17735
#        5     C     2.91643  2.91643  0.00000  0.16714
#        6     C     3.03688  3.03688  0.00000 -0.07377
#        7     C     2.96538  2.96538  0.00000  0.06924
#        8     O     4.10540  4.10540  0.00000 -0.21080
#        9     C     2.96498  2.96498  0.00000  0.07004
#       10     C     2.97958  2.97958  0.00000  0.04084
#       11     O     4.10538  4.10538  0.00000 -0.21077
#       12     O     4.09783  4.09783  0.00000 -0.19567
#       13     C     2.85046  2.85046  0.00000  0.29909
#       14     O     4.12756  4.12756  0.00000 -0.25513
#       15     N     3.61778  3.61778  0.00000 -0.23555
#       16     C     2.88697  2.88697  0.00000  0.22605
#       17     O     4.10691  4.10691  0.00000 -0.21382
#       18     H     0.47937  0.47937  0.00000  0.04127
#       19     H     0.47969  0.47969  0.00000  0.04063
#       20     H     0.48304  0.48304  0.00000  0.03393
#       21     H     0.47676  0.47676  0.00000  0.04648
#       22     H     0.48668  0.48668  0.00000  0.02664
#       23     H     0.47928  0.47928  0.00000  0.04144
#       24     H     0.48184  0.48184  0.00000  0.03632
#       25     H     0.48485  0.48485  0.00000  0.03029
#       26     H     0.43491  0.43491  0.00000  0.13018
#       27     H     0.48936  0.48936  0.00000  0.02128
#       28     H     0.48979  0.48979  0.00000  0.02042
#       29     H     0.48319  0.48319  0.00000  0.03362
#       30     H     0.43300  0.43300  0.00000  0.13399
#       31     H     0.42595  0.42595  0.00000  0.14811
#
#   Total alpha = 64.00000, Total beta = 64.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.09926  3.09926  0.00000 -0.19852
#        2     S     7.91984  7.91984  0.00000  0.16033
#        3     C     3.09855  3.09855  0.00000 -0.19710
#        4     C     2.99575  2.99575  0.00000  0.00849
#        5     C     3.03385  3.03385  0.00000 -0.06769
#        6     C     3.03097  3.03097  0.00000 -0.06193
#        7     C     3.03270  3.03270  0.00000 -0.06540
#        8     C     3.03102  3.03102  0.00000 -0.06203
#        9     C     3.03400  3.03400  0.00000 -0.06800
#       10     C     2.99702  2.99702  0.00000  0.00597
#       11     C     3.03551  3.03551  0.00000 -0.07102
#       12     C     3.03131  3.03131  0.00000 -0.06261
#       13     C     3.03301  3.03301  0.00000 -0.06602
#       14     C     3.03098  3.03098  0.00000 -0.06196
#       15     C     3.03433  3.03433  0.00000 -0.06865
#       16     H     0.46513  0.46513  0.00000  0.06975
#       17     H     0.46931  0.46931  0.00000  0.06138
#       18     H     0.46988  0.46988  0.00000  0.06023
#       19     H     0.46715  0.46715  0.00000  0.06569
#       20     H     0.46923  0.46923  0.00000  0.06153
#       21     H     0.46846  0.46846  0.00000  0.06307
#       22     H     0.46876  0.46876  0.00000  0.06248
#       23     H     0.46856  0.46856  0.00000  0.06288
#       24     H     0.46991  0.46991  0.00000  0.06018
#       25     H     0.47087  0.47087  0.00000  0.05825
#       26     H     0.46857  0.46857  0.00000  0.06285
#       27     H     0.46867  0.46867  0.00000  0.06266
#       28     H     0.46831  0.46831  0.00000  0.06338
#       29     H     0.46909  0.46909  0.00000  0.06182
#
#    Total alpha = 57.00000, Total beta = 57.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.06643  3.06643  0.00000 -0.13285
#        2     S     7.91528  7.91528  0.00000  0.16943
#        3     C     3.06565  3.06565  0.00000 -0.13130
#        4     C     2.99295  2.99295  0.00000  0.01410
#        5     C     3.01985  3.01985  0.00000 -0.03970
#        6     C     3.01461  3.01461  0.00000 -0.02923
#        7     C     3.01701  3.01701  0.00000 -0.03402
#        8     C     3.01469  3.01469  0.00000 -0.02938
#        9     C     3.02008  3.02008  0.00000 -0.04017
#       10     C     2.99493  2.99493  0.00000  0.01013
#       11     C     3.02161  3.02161  0.00000 -0.04321
#       12     C     3.01495  3.01495  0.00000 -0.02991
#       13     C     3.01735  3.01735  0.00000 -0.03471
#       14     C     3.01453  3.01453  0.00000 -0.02905
#       15     C     3.02009  3.02009  0.00000 -0.04018
#       16     H     0.48209  0.48209  0.00000  0.03582
#       17     H     0.48638  0.48638  0.00000  0.02724
#       18     H     0.48688  0.48688  0.00000  0.02623
#       19     H     0.48477  0.48477  0.00000  0.03047
#       20     H     0.48514  0.48514  0.00000  0.02973
#       21     H     0.48454  0.48454  0.00000  0.03092
#       22     H     0.48476  0.48476  0.00000  0.03049
#       23     H     0.48461  0.48461  0.00000  0.03078
#       24     H     0.48565  0.48565  0.00000  0.02869
#       25     H     0.48637  0.48637  0.00000  0.02726
#       26     H     0.48462  0.48462  0.00000  0.03076
#       27     H     0.48469  0.48469  0.00000  0.03063
#       28     H     0.48443  0.48443  0.00000  0.03114
#       29     H     0.48506  0.48506  0.00000  0.02989
#
#   Total alpha = 57.00000, Total beta = 57.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     O     4.08840  4.08840  0.00000 -0.17679
#        2     N     3.43639  3.43639  0.00000  0.12722
#        3     O     4.09344  4.09344  0.00000 -0.18687
#        4     C     2.95945  2.95945  0.00000  0.08111
#        5     C     3.02406  3.02406  0.00000 -0.04812
#        6     C     3.02540  3.02540  0.00000 -0.05079
#        7     C     3.02367  3.02367  0.00000 -0.04733
#        8     C     3.02694  3.02694  0.00000 -0.05389
#        9     C     3.04591  3.04591  0.00000 -0.09183
#       10     S     7.92392  7.92392  0.00000  0.15217
#       11     S     7.91604  7.91604  0.00000  0.16792
#       12     C     3.01921  3.01921  0.00000 -0.03842
#       13     C     2.96203  2.96203  0.00000  0.07595
#       14    CL     8.54288  8.54288  0.00000 -0.08577
#       15    CL     8.53111  8.53111  0.00000 -0.06222
#       16    CL     8.55054  8.55054  0.00000 -0.10109
#       17     H     0.45037  0.45037  0.00000  0.09926
#       18     H     0.45887  0.45887  0.00000  0.08226
#       19     H     0.45965  0.45965  0.00000  0.08070
#       20     H     0.46173  0.46173  0.00000  0.07654
#
#    Total alpha = 79.00000, Total beta = 79.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     O     4.10307  4.10307  0.00000 -0.20614
#        2     N     3.37988  3.37988  0.00000  0.24023
#        3     O     4.10812  4.10812  0.00000 -0.21623
#        4     C     2.97721  2.97721  0.00000  0.04558
#        5     C     3.00893  3.00893  0.00000 -0.01787
#        6     C     3.00855  3.00855  0.00000 -0.01710
#        7     C     3.00591  3.00591  0.00000 -0.01183
#        8     C     3.01316  3.01316  0.00000 -0.02632
#        9     C     3.04659  3.04659  0.00000 -0.09319
#       10     S     7.92339  7.92339  0.00000  0.15322
#       11     S     7.91711  7.91711  0.00000  0.16579
#       12     C     3.03696  3.03696  0.00000 -0.07392
#       13     C     2.98584  2.98584  0.00000  0.02832
#       14    CL     8.52820  8.52820  0.00000 -0.05640
#       15    CL     8.51715  8.51715  0.00000 -0.03429
#       16    CL     8.53510  8.53510  0.00000 -0.07020
#       17     H     0.47036  0.47036  0.00000  0.05928
#       18     H     0.47718  0.47718  0.00000  0.04565
#       19     H     0.47780  0.47780  0.00000  0.04440
#       20     H     0.47949  0.47949  0.00000  0.04102
#
#   Total alpha = 79.00000, Total beta = 79.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.09029  3.09029  0.00000 -0.18058
#        2     C     3.01271  3.01271  0.00000 -0.02542
#        3     C     3.05077  3.05077  0.00000 -0.10154
#        4     C     3.06439  3.06439  0.00000 -0.12879
#        5     C     2.84554  2.84554  0.00000  0.30892
#        6     O     4.13619  4.13619  0.00000 -0.27238
#        7     O     4.14851  4.14851  0.00000 -0.29702
#        8     C     3.01929  3.01929  0.00000 -0.03857
#        9     C     3.05464  3.05464  0.00000 -0.10928
#       10     C     3.05318  3.05318  0.00000 -0.10637
#       11     C     3.01979  3.01979  0.00000 -0.03958
#       12     C     3.01734  3.01734  0.00000 -0.03467
#       13     C     3.05667  3.05667  0.00000 -0.11335
#       14     C     3.05304  3.05304  0.00000 -0.10609
#       15     C     3.01676  3.01676  0.00000 -0.03352
#       16     C     3.06017  3.06017  0.00000 -0.12033
#       17     C     2.96230  2.96230  0.00000  0.07541
#       18     O     4.14709  4.14709  0.00000 -0.29418
#       19     C     3.05433  3.05433  0.00000 -0.10866
#       20     C     3.05440  3.05440  0.00000 -0.10880
#       21     C     2.97915  2.97915  0.00000  0.04169
#       22     C     3.09562  3.09562  0.00000 -0.19124
#       23     C     3.01840  3.01840  0.00000 -0.03679
#       24     C     3.06183  3.06183  0.00000 -0.12365
#       25     C     2.96508  2.96508  0.00000  0.06984
#       26     O     4.14934  4.14934  0.00000 -0.29869
#       27     C     2.98429  2.98429  0.00000  0.03141
#       28     C     3.09094  3.09094  0.00000 -0.18188
#       29     H     0.47193  0.47193  0.00000  0.05615
#       30     H     0.47238  0.47238  0.00000  0.05525
#       31     H     0.47183  0.47183  0.00000  0.05635
#       32     H     0.47419  0.47419  0.00000  0.05161
#       33     H     0.47263  0.47263  0.00000  0.05475
#       34     H     0.46637  0.46637  0.00000  0.06725
#       35     H     0.46329  0.46329  0.00000  0.07342
#       36     H     0.46207  0.46207  0.00000  0.07586
#       37     H     0.39937  0.39937  0.00000  0.20126
#       38     H     0.47803  0.47803  0.00000  0.04393
#       39     H     0.47287  0.47287  0.00000  0.05425
#       40     H     0.47558  0.47558  0.00000  0.04885
#       41     H     0.47418  0.47418  0.00000  0.05165
#       42     H     0.47638  0.47638  0.00000  0.04724
#       43     H     0.47579  0.47579  0.00000  0.04843
#       44     H     0.47737  0.47737  0.00000  0.04526
#       45     H     0.46516  0.46516  0.00000  0.06968
#       46     H     0.47601  0.47601  0.00000  0.04798
#       47     H     0.47581  0.47581  0.00000  0.04838
#       48     H     0.47510  0.47510  0.00000  0.04981
#       49     H     0.47500  0.47500  0.00000  0.05000
#       50     H     0.47490  0.47490  0.00000  0.05020
#       51     H     0.47455  0.47455  0.00000  0.05090
#       52     H     0.48077  0.48077  0.00000  0.03847
#       53     H     0.41687  0.41687  0.00000  0.16626
#       54     H     0.46958  0.46958  0.00000  0.06084
#       55     H     0.47168  0.47168  0.00000  0.05665
#       56     H     0.47605  0.47605  0.00000  0.04791
#       57     H     0.47458  0.47458  0.00000  0.05083
#       58     H     0.47359  0.47359  0.00000  0.05282
#       59     H     0.47619  0.47619  0.00000  0.04761
#       60     H     0.46480  0.46480  0.00000  0.07039
#       61     H     0.47768  0.47768  0.00000  0.04464
#       62     H     0.47353  0.47353  0.00000  0.05293
#       63     H     0.47515  0.47515  0.00000  0.04970
#       64     H     0.48147  0.48147  0.00000  0.03706
#       65     H     0.41412  0.41412  0.00000  0.17175
#       66     H     0.46480  0.46480  0.00000  0.07040
#       67     H     0.47363  0.47363  0.00000  0.05274
#       68     H     0.47267  0.47267  0.00000  0.05465
#
#    Total alpha = 108.00000, Total beta = 108.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04650  3.04650  0.00000 -0.09300
#        2     C     2.99600  2.99600  0.00000  0.00799
#        3     C     3.01984  3.01984  0.00000 -0.03967
#        4     C     3.03476  3.03476  0.00000 -0.06952
#        5     C     2.88485  2.88485  0.00000  0.23029
#        6     O     4.10839  4.10839  0.00000 -0.21679
#        7     O     4.10214  4.10214  0.00000 -0.20428
#        8     C     3.00539  3.00539  0.00000 -0.01077
#        9     C     3.02416  3.02416  0.00000 -0.04831
#       10     C     3.02324  3.02324  0.00000 -0.04648
#       11     C     3.00532  3.00532  0.00000 -0.01065
#       12     C     3.00142  3.00142  0.00000 -0.00284
#       13     C     3.02656  3.02656  0.00000 -0.05312
#       14     C     3.02318  3.02318  0.00000 -0.04637
#       15     C     3.00103  3.00103  0.00000 -0.00205
#       16     C     3.03202  3.03202  0.00000 -0.06403
#       17     C     2.95575  2.95575  0.00000  0.08849
#       18     O     4.10751  4.10751  0.00000 -0.21503
#       19     C     3.02400  3.02400  0.00000 -0.04799
#       20     C     3.02513  3.02513  0.00000 -0.05025
#       21     C     2.97731  2.97731  0.00000  0.04539
#       22     C     3.05311  3.05311  0.00000 -0.10622
#       23     C     3.00411  3.00411  0.00000 -0.00822
#       24     C     3.03381  3.03381  0.00000 -0.06762
#       25     C     2.95932  2.95932  0.00000  0.08135
#       26     O     4.10901  4.10901  0.00000 -0.21801
#       27     C     2.98357  2.98357  0.00000  0.03285
#       28     C     3.04764  3.04764  0.00000 -0.09529
#       29     H     0.48680  0.48680  0.00000  0.02641
#       30     H     0.48708  0.48708  0.00000  0.02584
#       31     H     0.48668  0.48668  0.00000  0.02664
#       32     H     0.48992  0.48992  0.00000  0.02017
#       33     H     0.48846  0.48846  0.00000  0.02308
#       34     H     0.48312  0.48312  0.00000  0.03376
#       35     H     0.48056  0.48056  0.00000  0.03888
#       36     H     0.47910  0.47910  0.00000  0.04179
#       37     H     0.42757  0.42757  0.00000  0.14486
#       38     H     0.49273  0.49273  0.00000  0.01455
#       39     H     0.48836  0.48836  0.00000  0.02328
#       40     H     0.49039  0.49039  0.00000  0.01923
#       41     H     0.48945  0.48945  0.00000  0.02111
#       42     H     0.49118  0.49118  0.00000  0.01765
#       43     H     0.49127  0.49127  0.00000  0.01746
#       44     H     0.49265  0.49265  0.00000  0.01471
#       45     H     0.48214  0.48214  0.00000  0.03572
#       46     H     0.49072  0.49072  0.00000  0.01855
#       47     H     0.49084  0.49084  0.00000  0.01832
#       48     H     0.49017  0.49017  0.00000  0.01967
#       49     H     0.49072  0.49072  0.00000  0.01856
#       50     H     0.48941  0.48941  0.00000  0.02117
#       51     H     0.48940  0.48940  0.00000  0.02119
#       52     H     0.49753  0.49753  0.00000  0.00494
#       53     H     0.44264  0.44264  0.00000  0.11473
#       54     H     0.48562  0.48562  0.00000  0.02876
#       55     H     0.48751  0.48751  0.00000  0.02497
#       56     H     0.49091  0.49091  0.00000  0.01818
#       57     H     0.48958  0.48958  0.00000  0.02085
#       58     H     0.48762  0.48762  0.00000  0.02476
#       59     H     0.48964  0.48964  0.00000  0.02071
#       60     H     0.48066  0.48066  0.00000  0.03869
#       61     H     0.49287  0.49287  0.00000  0.01426
#       62     H     0.48822  0.48822  0.00000  0.02356
#       63     H     0.48951  0.48951  0.00000  0.02098
#       64     H     0.49778  0.49778  0.00000  0.00445
#       65     H     0.44017  0.44017  0.00000  0.11965
#       66     H     0.48109  0.48109  0.00000  0.03781
#       67     H     0.48775  0.48775  0.00000  0.02451
#       68     H     0.48712  0.48712  0.00000  0.02575
#
#   Total alpha = 108.00000, Total beta = 108.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.03012  3.03012  0.00000 -0.06024
#        2     O     4.11760  4.11760  0.00000 -0.23521
#        3     C     2.93732  2.93732  0.00000  0.12535
#        4     C     3.05075  3.05075  0.00000 -0.10151
#        5     C     3.02848  3.02848  0.00000 -0.05696
#        6     C     3.00355  3.00355  0.00000 -0.00710
#        7     C     3.00328  3.00328  0.00000 -0.00655
#        8     O     4.09372  4.09372  0.00000 -0.18743
#        9     C     2.99720  2.99720  0.00000  0.00560
#       10     C     3.01195  3.01195  0.00000 -0.02390
#       11     C     3.05211  3.05211  0.00000 -0.10422
#       12     C     3.05146  3.05146  0.00000 -0.10292
#       13     C     3.05143  3.05143  0.00000 -0.10286
#       14     C     3.05172  3.05172  0.00000 -0.10344
#       15     C     3.01752  3.01752  0.00000 -0.03505
#       16     C     2.99527  2.99527  0.00000  0.00946
#       17     C     3.04427  3.04427  0.00000 -0.08855
#       18     H     0.46725  0.46725  0.00000  0.06550
#       19     H     0.46149  0.46149  0.00000  0.07702
#       20     H     0.46724  0.46724  0.00000  0.06551
#       21     H     0.46804  0.46804  0.00000  0.06393
#       22     H     0.46524  0.46524  0.00000  0.06952
#       23     H     0.47015  0.47015  0.00000  0.05970
#       24     H     0.47194  0.47194  0.00000  0.05611
#       25     H     0.47148  0.47148  0.00000  0.05704
#       26     H     0.47105  0.47105  0.00000  0.05789
#       27     H     0.47288  0.47288  0.00000  0.05423
#       28     H     0.47439  0.47439  0.00000  0.05122
#       29     H     0.47216  0.47216  0.00000  0.05569
#       30     H     0.47281  0.47281  0.00000  0.05438
#       31     H     0.47377  0.47377  0.00000  0.05247
#       32     H     0.47414  0.47414  0.00000  0.05171
#       33     H     0.47053  0.47053  0.00000  0.05893
#       34     H     0.47206  0.47206  0.00000  0.05588
#       35     H     0.46560  0.46560  0.00000  0.06879
#
#    Total alpha = 62.00000, Total beta = 62.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     2.99449  2.99449  0.00000  0.01101
#        2     O     4.07869  4.07869  0.00000 -0.15738
#        3     C     2.94648  2.94648  0.00000  0.10703
#        4     C     3.04203  3.04203  0.00000 -0.08406
#        5     C     3.01235  3.01235  0.00000 -0.02470
#        6     C     3.00679  3.00679  0.00000 -0.01358
#        7     C     2.99269  2.99269  0.00000  0.01462
#        8     O     4.06967  4.06967  0.00000 -0.13934
#        9     C     2.98762  2.98762  0.00000  0.02477
#       10     C     2.99673  2.99673  0.00000  0.00654
#       11     C     3.02185  3.02185  0.00000 -0.04371
#       12     C     3.02052  3.02052  0.00000 -0.04103
#       13     C     3.02081  3.02081  0.00000 -0.04161
#       14     C     3.02156  3.02156  0.00000 -0.04313
#       15     C     3.00054  3.00054  0.00000 -0.00108
#       16     C     2.99295  2.99295  0.00000  0.01410
#       17     C     3.03525  3.03525  0.00000 -0.07051
#       18     H     0.48502  0.48502  0.00000  0.02996
#       19     H     0.47966  0.47966  0.00000  0.04068
#       20     H     0.48502  0.48502  0.00000  0.02996
#       21     H     0.48340  0.48340  0.00000  0.03321
#       22     H     0.48186  0.48186  0.00000  0.03627
#       23     H     0.48863  0.48863  0.00000  0.02274
#       24     H     0.49033  0.49033  0.00000  0.01934
#       25     H     0.48828  0.48828  0.00000  0.02343
#       26     H     0.48702  0.48702  0.00000  0.02596
#       27     H     0.48847  0.48847  0.00000  0.02305
#       28     H     0.48980  0.48980  0.00000  0.02039
#       29     H     0.48790  0.48790  0.00000  0.02420
#       30     H     0.48842  0.48842  0.00000  0.02316
#       31     H     0.48927  0.48927  0.00000  0.02146
#       32     H     0.48956  0.48956  0.00000  0.02089
#       33     H     0.48628  0.48628  0.00000  0.02744
#       34     H     0.48843  0.48843  0.00000  0.02314
#       35     H     0.48162  0.48162  0.00000  0.03676
#
#   Total alpha = 62.00000, Total beta = 62.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     O     4.14432  4.14432  0.00000 -0.28864
#        2     C     2.84310  2.84310  0.00000  0.31379
#        3     O     4.12833  4.12833  0.00000 -0.25666
#        4     C     3.09963  3.09963  0.00000 -0.19925
#        5     I    26.48922 26.48922  0.00000  0.02156
#        6     H     0.39503  0.39503  0.00000  0.20994
#        7     H     0.45067  0.45067  0.00000  0.09866
#        8     H     0.44969  0.44969  0.00000  0.10061
#
#    Total alpha = 42.00000, Total beta = 42.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     O     4.09809  4.09809  0.00000 -0.19618
#        2     C     2.88457  2.88457  0.00000  0.23086
#        3     O     4.10103  4.10103  0.00000 -0.20205
#        4     C     3.06370  3.06370  0.00000 -0.12739
#        5     I    26.48687 26.48687  0.00000  0.02626
#        6     H     0.42386  0.42386  0.00000  0.15228
#        7     H     0.47126  0.47126  0.00000  0.05748
#        8     H     0.47063  0.47063  0.00000  0.05875
#
#   Total alpha = 42.00000, Total beta = 42.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.08910  3.08910  0.00000 -0.17820
#        2     C     3.04758  3.04758  0.00000 -0.09517
#        3     C     3.05009  3.05009  0.00000 -0.10019
#        4     C     3.05002  3.05002  0.00000 -0.10005
#        5     C     3.04932  3.04932  0.00000 -0.09863
#        6     C     3.05011  3.05011  0.00000 -0.10022
#        7     C     3.04900  3.04900  0.00000 -0.09800
#        8     C     3.05027  3.05027  0.00000 -0.10054
#        9     C     3.04889  3.04889  0.00000 -0.09778
#       10     C     3.04741  3.04741  0.00000 -0.09482
#       11     C     3.08955  3.08955  0.00000 -0.17909
#       12     H     0.47195  0.47195  0.00000  0.05611
#       13     H     0.47205  0.47205  0.00000  0.05589
#       14     H     0.47141  0.47141  0.00000  0.05718
#       15     H     0.47366  0.47366  0.00000  0.05269
#       16     H     0.47486  0.47486  0.00000  0.05029
#       17     H     0.47498  0.47498  0.00000  0.05005
#       18     H     0.47506  0.47506  0.00000  0.04988
#       19     H     0.47492  0.47492  0.00000  0.05016
#       20     H     0.47442  0.47442  0.00000  0.05117
#       21     H     0.47472  0.47472  0.00000  0.05056
#       22     H     0.47582  0.47582  0.00000  0.04836
#       23     H     0.47558  0.47558  0.00000  0.04885
#       24     H     0.47435  0.47435  0.00000  0.05131
#       25     H     0.47513  0.47513  0.00000  0.04973
#       26     H     0.47546  0.47546  0.00000  0.04908
#       27     H     0.47450  0.47450  0.00000  0.05101
#       28     H     0.47581  0.47581  0.00000  0.04838
#       29     H     0.47539  0.47539  0.00000  0.04923
#       30     H     0.47501  0.47501  0.00000  0.04998
#       31     H     0.47412  0.47412  0.00000  0.05177
#       32     H     0.47458  0.47458  0.00000  0.05084
#       33     H     0.47154  0.47154  0.00000  0.05693
#       34     H     0.47203  0.47203  0.00000  0.05593
#       35     H     0.47133  0.47133  0.00000  0.05734
#
#    Total alpha = 45.00000, Total beta = 45.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04451  3.04451  0.00000 -0.08903
#        2     C     3.01646  3.01646  0.00000 -0.03292
#        3     C     3.02007  3.02007  0.00000 -0.04013
#        4     C     3.01976  3.01976  0.00000 -0.03952
#        5     C     3.01912  3.01912  0.00000 -0.03824
#        6     C     3.01986  3.01986  0.00000 -0.03972
#        7     C     3.01866  3.01866  0.00000 -0.03731
#        8     C     3.02023  3.02023  0.00000 -0.04046
#        9     C     3.01864  3.01864  0.00000 -0.03728
#       10     C     3.01612  3.01612  0.00000 -0.03224
#       11     C     3.04508  3.04508  0.00000 -0.09016
#       12     H     0.48687  0.48687  0.00000  0.02626
#       13     H     0.48695  0.48695  0.00000  0.02610
#       14     H     0.48638  0.48638  0.00000  0.02723
#       15     H     0.48909  0.48909  0.00000  0.02182
#       16     H     0.49015  0.49015  0.00000  0.01970
#       17     H     0.49017  0.49017  0.00000  0.01966
#       18     H     0.49007  0.49007  0.00000  0.01985
#       19     H     0.49000  0.49000  0.00000  0.02000
#       20     H     0.48967  0.48967  0.00000  0.02065
#       21     H     0.48984  0.48984  0.00000  0.02032
#       22     H     0.49088  0.49088  0.00000  0.01824
#       23     H     0.49065  0.49065  0.00000  0.01871
#       24     H     0.48951  0.48951  0.00000  0.02099
#       25     H     0.49034  0.49034  0.00000  0.01933
#       26     H     0.49059  0.49059  0.00000  0.01882
#       27     H     0.48955  0.48955  0.00000  0.02090
#       28     H     0.49085  0.49085  0.00000  0.01831
#       29     H     0.49055  0.49055  0.00000  0.01890
#       30     H     0.49024  0.49024  0.00000  0.01952
#       31     H     0.48957  0.48957  0.00000  0.02085
#       32     H     0.48994  0.48994  0.00000  0.02012
#       33     H     0.48643  0.48643  0.00000  0.02714
#       34     H     0.48691  0.48691  0.00000  0.02618
#       35     H     0.48630  0.48630  0.00000  0.02740
#
#   Total alpha = 45.00000, Total beta = 45.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.09344  3.09344  0.00000 -0.18688
#        2     C     2.94088  2.94088  0.00000  0.11824
#        3     C     3.04053  3.04053  0.00000 -0.08107
#        4     C     3.02519  3.02519  0.00000 -0.05039
#        5     C     3.00529  3.00529  0.00000 -0.01057
#        6     C     3.03082  3.03082  0.00000 -0.06164
#        7     C     3.03077  3.03077  0.00000 -0.06155
#        8     C     3.03142  3.03142  0.00000 -0.06285
#        9     C     3.02873  3.02873  0.00000 -0.05746
#       10     C     2.95915  2.95915  0.00000  0.08170
#       11     N     3.62719  3.62719  0.00000 -0.25438
#       12     H     0.45972  0.45972  0.00000  0.08056
#       13     H     0.46629  0.46629  0.00000  0.06741
#       14     H     0.46630  0.46630  0.00000  0.06741
#       15     H     0.46585  0.46585  0.00000  0.06829
#       16     H     0.46485  0.46485  0.00000  0.07031
#       17     H     0.46808  0.46808  0.00000  0.06383
#       18     H     0.46720  0.46720  0.00000  0.06560
#       19     H     0.46690  0.46690  0.00000  0.06619
#       20     H     0.46138  0.46138  0.00000  0.07725
#
#    Total alpha = 38.00000, Total beta = 38.00000, Total charge = -0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04866  3.04866  0.00000 -0.09733
# ...
#       26     H     0.48181  0.48181  0.00000  0.03639
#       27     H     0.48078  0.48078  0.00000  0.03844
#       28     H     0.48071  0.48071  0.00000  0.03858
#       29     H     0.47941  0.47941  0.00000  0.04117
#       30     H     0.48180  0.48180  0.00000  0.03640
#       31     H     0.47297  0.47297  0.00000  0.05406
#
#   Total alpha = 61.00000, Total beta = 61.00000, Total charge = -0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     N     3.70485  3.70485  0.00000 -0.40971
#        2     C     2.93858  2.93858  0.00000  0.12284
#        3     C     3.04443  3.04443  0.00000 -0.08887
#        4     C     3.02180  3.02180  0.00000 -0.04360
#        5     C     3.04133  3.04133  0.00000 -0.08265
#        6     C     3.02155  3.02155  0.00000 -0.04311
#        7     C     3.02710  3.02710  0.00000 -0.05420
#        8     C     2.84441  2.84441  0.00000  0.31119
#        9     O     4.14288  4.14288  0.00000 -0.28576
#       10     O     4.12655  4.12655  0.00000 -0.25311
#       11     C     2.99457  2.99457  0.00000  0.01085
#       12     C     3.02937  3.02937  0.00000 -0.05874
#       13     C     3.02904  3.02904  0.00000 -0.05808
#       14     C     2.99858  2.99858  0.00000  0.00285
#       15     C     3.03112  3.03112  0.00000 -0.06224
#       16     C     3.03130  3.03130  0.00000 -0.06261
#       17     C     3.03091  3.03091  0.00000 -0.06182
#       18     C     3.03177  3.03177  0.00000 -0.06353
#       19     C     3.03075  3.03075  0.00000 -0.06150
#       20     H     0.39419  0.39419  0.00000  0.21161
#       21     H     0.41509  0.41509  0.00000  0.16981
#       22     H     0.46862  0.46862  0.00000  0.06275
#       23     H     0.46602  0.46602  0.00000  0.06796
#       24     H     0.46852  0.46852  0.00000  0.06295
#       25     H     0.45869  0.45869  0.00000  0.08261
#       26     H     0.46480  0.46480  0.00000  0.07040
#       27     H     0.46471  0.46471  0.00000  0.07057
#       28     H     0.46741  0.46741  0.00000  0.06518
#       29     H     0.46954  0.46954  0.00000  0.06092
#       30     H     0.46835  0.46835  0.00000  0.06329
#       31     H     0.46811  0.46811  0.00000  0.06379
#       32     H     0.46790  0.46790  0.00000  0.06419
#       33     H     0.46792  0.46792  0.00000  0.06417
#       34     H     0.46920  0.46920  0.00000  0.06160
#
#    Total alpha = 67.00000, Total beta = 67.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     N     3.62948  3.62948  0.00000 -0.25896
#        2     C     2.94448  2.94448  0.00000  0.11105
#        3     C     3.03561  3.03561  0.00000 -0.07122
#        4     C     3.00206  3.00206  0.00000 -0.00411
#        5     C     3.02924  3.02924  0.00000 -0.05848
#        6     C     3.00286  3.00286  0.00000 -0.00572
#        7     C     3.03710  3.03710  0.00000 -0.07419
#        8     C     2.88208  2.88208  0.00000  0.23585
#        9     O     4.11537  4.11537  0.00000 -0.23073
#       10     O     4.08979  4.08979  0.00000 -0.17957
#       11     C     2.97041  2.97041  0.00000  0.05917
#       12     C     3.01662  3.01662  0.00000 -0.03325
#       13     C     3.01405  3.01405  0.00000 -0.02809
#       14     C     2.99509  2.99509  0.00000  0.00982
#       15     C     3.01654  3.01654  0.00000 -0.03308
#       16     C     3.01528  3.01528  0.00000 -0.03057
#       17     C     3.01464  3.01464  0.00000 -0.02927
#       18     C     3.01563  3.01563  0.00000 -0.03125
#       19     C     3.01633  3.01633  0.00000 -0.03266
#       20     H     0.42723  0.42723  0.00000  0.14553
#       21     H     0.44350  0.44350  0.00000  0.11300
#       22     H     0.48436  0.48436  0.00000  0.03129
#       23     H     0.48268  0.48268  0.00000  0.03465
#       24     H     0.48448  0.48448  0.00000  0.03104
#       25     H     0.47701  0.47701  0.00000  0.04597
#       26     H     0.48382  0.48382  0.00000  0.03236
#       27     H     0.48367  0.48367  0.00000  0.03266
#       28     H     0.48343  0.48343  0.00000  0.03314
#       29     H     0.48535  0.48535  0.00000  0.02929
#       30     H     0.48420  0.48420  0.00000  0.03160
#       31     H     0.48428  0.48428  0.00000  0.03143
#       32     H     0.48411  0.48411  0.00000  0.03177
#       33     H     0.48411  0.48411  0.00000  0.03179
#       34     H     0.48512  0.48512  0.00000  0.02976
#
#   Total alpha = 67.00000, Total beta = 67.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.09230  3.09230  0.00000 -0.18459
#        2     C     2.99402  2.99402  0.00000  0.01195
#        3     C     3.03430  3.03430  0.00000 -0.06859
#        4     C     3.03393  3.03393  0.00000 -0.06786
#        5     C     2.99554  2.99554  0.00000  0.00891
#        6     C     3.05514  3.05514  0.00000 -0.11028
#        7     C     2.99334  2.99334  0.00000  0.01332
#        8     C     3.03476  3.03476  0.00000 -0.06952
#        9     C     3.03106  3.03106  0.00000 -0.06213
#       10     C     3.03321  3.03321  0.00000 -0.06643
#       11     C     3.03091  3.03091  0.00000 -0.06181
#       12     C     3.03440  3.03440  0.00000 -0.06880
#       13     C     3.03427  3.03427  0.00000 -0.06854
#       14     C     3.03451  3.03451  0.00000 -0.06902
#       15     H     0.46752  0.46752  0.00000  0.06496
#       16     H     0.46765  0.46765  0.00000  0.06471
#       17     H     0.46648  0.46648  0.00000  0.06705
#       18     H     0.47061  0.47061  0.00000  0.05878
#       19     H     0.47047  0.47047  0.00000  0.05906
#       20     H     0.46793  0.46793  0.00000  0.06415
#       21     H     0.46797  0.46797  0.00000  0.06406
#       22     H     0.47085  0.47085  0.00000  0.05831
#       23     H     0.46890  0.46890  0.00000  0.06219
#       24     H     0.46908  0.46908  0.00000  0.06184
#       25     H     0.46881  0.46881  0.00000  0.06237
#       26     H     0.47017  0.47017  0.00000  0.05966
#       27     H     0.47114  0.47114  0.00000  0.05772
#       28     H     0.47073  0.47073  0.00000  0.05854
#
#    Total alpha = 49.00000, Total beta = 49.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     C     3.04623  3.04623  0.00000 -0.09246
#        2     C     2.99075  2.99075  0.00000  0.01850
#        3     C     3.02013  3.02013  0.00000 -0.04026
#        4     C     3.01960  3.01960  0.00000 -0.03920
#        5     C     2.99320  2.99320  0.00000  0.01359
#        6     C     3.02216  3.02216  0.00000 -0.04432
#        7     C     2.99038  2.99038  0.00000  0.01925
#        8     C     3.02101  3.02101  0.00000 -0.04202
#        9     C     3.01470  3.01470  0.00000 -0.02940
#       10     C     3.01769  3.01769  0.00000 -0.03537
#       11     C     3.01452  3.01452  0.00000 -0.02903
#       12     C     3.02044  3.02044  0.00000 -0.04088
#       13     C     3.02015  3.02015  0.00000 -0.04029
#       14     C     3.02043  3.02043  0.00000 -0.04086
#       15     H     0.48308  0.48308  0.00000  0.03384
#       16     H     0.48319  0.48319  0.00000  0.03361
#       17     H     0.48207  0.48207  0.00000  0.03586
#       18     H     0.48618  0.48618  0.00000  0.02765
#       19     H     0.48605  0.48605  0.00000  0.02790
#       20     H     0.48419  0.48419  0.00000  0.03163
#       21     H     0.48424  0.48424  0.00000  0.03153
#       22     H     0.48633  0.48633  0.00000  0.02734
#       23     H     0.48487  0.48487  0.00000  0.03026
#       24     H     0.48500  0.48500  0.00000  0.03001
#       25     H     0.48481  0.48481  0.00000  0.03038
#       26     H     0.48584  0.48584  0.00000  0.02832
#       27     H     0.48653  0.48653  0.00000  0.02693
#       28     H     0.48625  0.48625  0.00000  0.02750
#
#   Total alpha = 49.00000, Total beta = 49.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     N     3.69347  3.69347  0.00000 -0.38694
#        2     C     2.88225  2.88225  0.00000  0.23550
#        3     N     3.64633  3.64633  0.00000 -0.29266
#        4     C     2.92670  2.92670  0.00000  0.14660
#        5     N     3.65190  3.65190  0.00000 -0.30379
#        6     C     2.90761  2.90761  0.00000  0.18478
#        7     C     2.99576  2.99576  0.00000  0.00848
#        8     N     3.63141  3.63141  0.00000 -0.26282
#        9     C     2.92660  2.92660  0.00000  0.14681
#       10     N     3.63517  3.63517  0.00000 -0.27035
#       11     C     2.91708  2.91708  0.00000  0.16584
#       12     O     4.13283  4.13283  0.00000 -0.26566
#       13     C     2.96737  2.96737  0.00000  0.06525
#       14     C     2.99933  2.99933  0.00000  0.00135
#       15     O     4.14251  4.14251  0.00000 -0.28501
#       16     C     3.06190  3.06190  0.00000 -0.12380
#       17     C     2.96435  2.96435  0.00000  0.07130
#       18     O     4.15583  4.15583  0.00000 -0.31166
#       19     H     0.39883  0.39883  0.00000  0.20235
#       20     H     0.39929  0.39929  0.00000  0.20142
#       21     H     0.45615  0.45615  0.00000  0.08769
#       22     H     0.44750  0.44750  0.00000  0.10501
#       23     H     0.46103  0.46103  0.00000  0.07794
#       24     H     0.46963  0.46963  0.00000  0.06075
#       25     H     0.47244  0.47244  0.00000  0.05513
#       26     H     0.46531  0.46531  0.00000  0.06938
#       27     H     0.40789  0.40789  0.00000  0.18422
#       28     H     0.46231  0.46231  0.00000  0.07537
#       29     H     0.46265  0.46265  0.00000  0.07470
#       30     H     0.47064  0.47064  0.00000  0.05872
#       31     H     0.38795  0.38795  0.00000  0.22411
#
#    Total alpha = 66.00000, Total beta = 66.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     N     3.61413  3.61413  0.00000 -0.22827
#        2     C     2.90369  2.90369  0.00000  0.19262
#        3     N     3.61965  3.61965  0.00000 -0.23930
#        4     C     2.93799  2.93799  0.00000  0.12402
#        5     N     3.61777  3.61777  0.00000 -0.23554
#        6     C     2.93820  2.93820  0.00000  0.12359
#        7     C     3.02126  3.02126  0.00000 -0.04251
#        8     N     3.60267  3.60267  0.00000 -0.20535
#        9     C     2.94706  2.94706  0.00000  0.10587
#       10     N     3.56450  3.56450  0.00000 -0.12900
#       11     C     2.92465  2.92465  0.00000  0.15070
#       12     O     4.10281  4.10281  0.00000 -0.20563
#       13     C     2.95992  2.95992  0.00000  0.08016
#       14     C     2.97932  2.97932  0.00000  0.04136
#       15     O     4.10167  4.10167  0.00000 -0.20333
#       16     C     3.03086  3.03086  0.00000 -0.06172
#       17     C     2.96001  2.96001  0.00000  0.07997
#       18     O     4.11522  4.11522  0.00000 -0.23044
#       19     H     0.43070  0.43070  0.00000  0.13859
#       20     H     0.43111  0.43111  0.00000  0.13778
#       21     H     0.47825  0.47825  0.00000  0.04350
#       22     H     0.46981  0.46981  0.00000  0.06038
#       23     H     0.48304  0.48304  0.00000  0.03392
#       24     H     0.48873  0.48873  0.00000  0.02253
#       25     H     0.49015  0.49015  0.00000  0.01970
#       26     H     0.48322  0.48322  0.00000  0.03356
#       27     H     0.43511  0.43511  0.00000  0.12979
#       28     H     0.47970  0.47970  0.00000  0.04060
#       29     H     0.48031  0.48031  0.00000  0.03938
#       30     H     0.48948  0.48948  0.00000  0.02104
#       31     H     0.41899  0.41899  0.00000  0.16201
#
#   Total alpha = 66.00000, Total beta = 66.00000, Total charge =  0.00000
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Mulliken Charges: (a.u.)
#    Center  Symbol    Alpha    Beta     Spin     Total
#        1     F     4.56253  4.56253  0.00000 -0.12506
#        2     C     2.93394  2.93394  0.00000  0.13211
#        3     C     2.99080  2.99080  0.00000  0.01840
#        4     N     3.61652  3.61652  0.00000 -0.23304
#        5     C     2.96193  2.96193  0.00000  0.07615
#        6     C     2.99645  2.99645  0.00000  0.00710
#        7     C     3.04008  3.04008  0.00000 -0.08016
#        8     C     3.04885  3.04885  0.00000 -0.09770
#        9     C     2.92605  2.92605  0.00000  0.14790
#       10     F     4.56500  4.56500  0.00000 -0.12999
#       11     C     3.00851  3.00851  0.00000 -0.01701
#       12     C     3.03063  3.03063  0.00000 -0.06126
#       13     C     3.03012  3.03012  0.00000 -0.06024
#       14     C     3.02990  3.02990  0.00000 -0.05980
#       15     C     3.02856  3.02856  0.00000 -0.05713
#       16     C     2.99527  2.99527  0.00000  0.00947
#       17     H     0.45941  0.45941  0.00000  0.08118
#       18     H     0.45977  0.45977  0.00000  0.08046
#       19     H     0.46314  0.46314  0.00000  0.07371
#       20     H     0.46379  0.46379  0.00000  0.07243
#       21     H     0.46632  0.46632  0.00000  0.06737
#       22     H     0.46619  0.46619  0.00000  0.06762
#       23     H     0.45626  0.45626  0.00000  0.08748
#
#    Total alpha = 55.00000, Total beta = 55.00000, Total charge =  0.00000
#
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
# OEProp: No title given, name of density matrix used for the following properties is 'Da'
#   Lowdin Charges: (a.u.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7253/3442327039.py in <module>
# ----> 1 train_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["train"],Ywf["train"],Zwf["train"])]
#       2 train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)
#       3
#       4 valid_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["valid"],Ywf["valid"],Zwf["valid"])]
#       5 valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)
#
# /tmp/ipykernel_7253/3442327039.py in <listcomp>(.0)
# ----> 1 train_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["train"],Ywf["train"],Zwf["train"])]
#       2 train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)
#       3
#       4 valid_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["valid"],Ywf["valid"],Zwf["valid"])]
#       5 valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)
#
# /tmp/ipykernel_7253/3577990272.py in mol2geodataWF(mol, y, z)
#      77     smile = Chem.MolToSmiles(mol)
#      78     atom_features =[get_atom_features(atom) for atom in mol.GetAtoms()]
# ---> 79     WF_results = get_WF_results(z)
#      80     atom_features = np.append(atom_features, WF_results, axis=1)
#      81     num_atom_features=len(atom_features[0])
#
# /tmp/ipykernel_7253/3577990272.py in get_WF_results(wf)
#      33     norm_M_charges = rescaling(M_charges)
#      34     #Löwdin電荷
# ---> 35     psi4.oeprop(wf, "LOWDIN_CHARGES")
#      36     L_charges = np.array(wf.atomic_point_charges())
#      37     norm_L_charges = rescaling(L_charges)
#
# ~/anaconda3/envs/chem/lib/python3.7/site-packages/psi4/driver/p4util/util.py in oeprop(wfn, *args, **kwargs)
#      65     for prop in args:
#      66         oe.add(prop)
# ---> 67     oe.compute()
#      68
#      69
#
# KeyboardInterrupt:

# %%
num_atom_features = train_data_list[0].num_atom_features
num_bond_features = train_data_list[0].num_bond_features

print("num_atom_features =",num_atom_features)
print("num_bond_features =",num_bond_features)

# %%
# ニューラルネットワークの構造の定義

import torch
import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU
import torch_geometric.transforms as T
from torch_geometric.nn import NNConv, Set2Set

dim = 64 # 中間層の次元

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.lin0 = torch.nn.Linear(num_atom_features, dim)

        nn = Sequential(Linear(num_bond_features, 128), ReLU(), Linear(128, dim * dim))
        self.conv = NNConv(dim, dim, nn, aggr='mean')
        self.gru = GRU(dim, dim)

        self.set2set = Set2Set(dim, processing_steps=3)
        self.lin1 = torch.nn.Linear(2 * dim, dim)
        self.lin2 = torch.nn.Linear(dim, 1)

    def forward(self, data):
        out = F.relu(self.lin0(data.x))
        h = out.unsqueeze(0)

        for i in range(3):
            m = F.relu(self.conv(out, data.edge_index, data.edge_attr))
            out, h = self.gru(m.unsqueeze(0), h)
            out = out.squeeze(0)

        out = self.set2set(out, data.batch)
        out = F.relu(self.lin1(out))
        out = self.lin2(out)
        return out.view(-1)

# %%
# ニューラルネットワークの学習パラメータの定義

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',factor=0.7, patience=5,min_lr=0.00001)
loss_function = torch.nn.BCEWithLogitsLoss()

def train_step(epoch):
    model.train()
    loss_all = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        loss = loss_function(model(data), data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_loader.dataset)

def test_step(loader):
    model.eval()
    loss_all = 0
    for data in loader:
        data = data.to(device)
        loss = loss_function(model(data), data.y)
        loss_all += loss.item() * data.num_graphs
    return loss_all / len(loader.dataset)

# %%
# 学習開始

best_valid_loss = None
for epoch in range(1, 1000,10):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train_step(epoch)
    valid_loss = test_step(valid_loader)
    scheduler.step(valid_loss)

    if best_valid_loss is None or valid_loss <= best_valid_loss:
        test_loss = test_step(test_loader)
        best_valid_loss = valid_loss

    print('Epoch: {:03d}, LR: {:7f}, Loss: {:.7f}, Validation loss: {:.7f}, '
          'Test loss: {:.7f}'.format(epoch, lr, loss, valid_loss, test_loss))
