# %%
### Pytorch geometry (グラフニューラルネットワークライブラリ) のインストール
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

# %%
# ライブラリ確認
import numpy as np
import pandas as pd
import rdkit
from rdkit import Chem
import torch
from torch_geometric.data import Data as TorchGeometricData

print(Chem.__doc__)
# Out:
#  A module for molecules and stuff
#
#  see Chem/index.html in the doc tree for documentation

# %%
#wavefunctionファイルの読み込み
import glob
import re
files = []
for file in glob.glob("../calculation/Ames_data/wavefunctions/*_Ames_wavefunction.npy"):
    files.append(file)

data_num = len(files)
print("start with {} wavefunctions".format(data_num))
# Out:
# start with 1483 wavefunctions

# %%
#wavefunctionの取り出し
import psi4

#スレッド数とメモリの設定
psi4.set_num_threads(nthread=5)
psi4.set_memory("10GB")

ID_list = []
wavefunction_list = []
for file in files:
    pre_ID = re.findall('../calculation/Ames_data/wavefunctions/(.*)_Ames_wavefunction.npy', file)
    ID = pre_ID[0]
    ID_list.append(int(ID))
    wave_function = psi4.core.Wavefunction.from_file(file)
    wavefunction_list.append(wave_function)
# Out:
#   Threads set to 5 by Python driver.
#
#   Memory set to   9.313 GiB by Python driver.
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 6-10, 12-19 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 20            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11                  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-41               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 6-7 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 8     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9           entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-20       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5, 7-8, 10-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6, 9, 12          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-28                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6-9, 14     entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 11          entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-5, 10, 12-13 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-28          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5    entry I          line  1083 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-8  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4, 6-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 5, 22-23  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21           entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-36        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-10   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 19-20 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 18       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-17        entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-28       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 5-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-29     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 5-11, 14-20  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-4, 12-13, 21-22 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-34             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-9, 11-16, 18, 20-23, 25 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 17, 19, 24                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10                           entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 26-44                        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-11  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1                         entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-7, 9-15, 17-24, 26 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 8, 16, 25              entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 27-47                     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-15, 18, 20-26, 28-39, 41, 43 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-17                          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19, 27, 40, 42                 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 44-95                          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8, 10-11, 13-14, 16-21, 23-25, 27-28, 30-31, 33-38, 40 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 12, 15, 22, 26, 29, 32, 39                            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 41-64                                                    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 15-16, 20-21 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 14, 19          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-13, 17-18        entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-28              entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5-12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 13   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-15      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-24      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5, 8-9, 11-15, 17-27, 29-30 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-7, 16                       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10                            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 28                            entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 31-52                         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 17                entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 9, 13-16, 18-19 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6, 11-12                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-8                     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10                      entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-24                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 6-7, 9-11, 13-14, 16-19, 21-22 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 8, 12, 15, 20                    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-34                                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-24  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-42 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5, 10, 12        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4, 6-9, 11, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-22               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 8    entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-6, 9-11 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 12-13  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-24     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 8  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-7   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-16 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3        entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-14     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-6, 8-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 7, 10      entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-14         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 9     entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 8  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6, 10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 7, 11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 12     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 8-11, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5              entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-7            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-24          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-5, 8-9, 11-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-7, 21         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10, 22-23       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-36           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2        entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-10     entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-16    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-10  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-13 entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-17 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5, 10, 12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6             entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7                entry P          line   167 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-9, 11          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-27            entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-6, 8-9, 11, 13-19, 21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 7, 10, 12, 20             entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-35                        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 10  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4-8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 9   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-22  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6-7, 15    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-5, 8-14, 16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-28         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 10          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 11             entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-7, 9, 12-16, 18 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8                 entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17                entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19-25             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 5-10, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 11-12         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4                entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-25            entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5, 8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 7      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6         entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-15     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-25     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-24, 26, 28-33 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25, 27, 34      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 35-86           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4, 7-12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3            entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-22        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4    entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-10 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-13 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-25   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 11    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-10, 12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-22    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-6, 8-9, 11-19, 21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2                      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 10, 20              entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-40                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8, 10, 12-15, 17-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 11, 22-23          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16, 21                entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-49                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 8, 10-11, 13, 15-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 9, 12, 14, 17         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-29                    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-15  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5-9, 14-20, 22-23, 25-26 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 24                       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-13, 21                      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 27-39                          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-19   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5, 9-10, 15-17 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 6-8, 11-12, 14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13                   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-27                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 8, 10-11, 13-19 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 7, 9, 12          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6                    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20-38                entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-9 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-5, 7-8, 10-17, 19-20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 6, 21                  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 18                     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-31                     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-7, 9-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 8         entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-20        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-20 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11      entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-18   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-7, 9, 11-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2                entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 10            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-38            entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 11     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12        entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-23     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4-7, 9-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2            entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8            entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-17        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4, 6-8, 10-12 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 13              entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 9, 14-15        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25              entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4-5, 8, 15  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 6-7, 9-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-7, 9-11, 13-15, 17-19, 21-24 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 12, 16, 20                  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-46                          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 7-8, 10, 12-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-6, 9, 11          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 15-28               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1           entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-10, 12-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-23       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4-18, 20 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 19          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-33       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2   entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3-5 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-9 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-7, 9-12, 14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 13, 16        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 15            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-30            entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5, 7-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 6       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-35         entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-12, 14-15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13          entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-37       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-15  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-24 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 23-24 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-21     entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-35    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 9-11 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 13     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 12     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-31     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 7, 16                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5-6, 8, 10, 12-13, 15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 11, 14                  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-27                      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-8, 10-13, 15-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 9, 14               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-36                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1                  entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-8, 10, 12-13, 15 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 14, 16          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11                 entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17                 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-23              entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-6, 8-9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2           entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7           entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-18       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6, 8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 7, 9   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-23     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5, 8, 11, 16, 18, 23                 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4, 6-7, 9-10, 12-15, 17, 19-22, 24-25 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 26-35                                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4, 6, 15            entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3, 5, 7-8, 11, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10, 12               entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1    entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-7  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-13 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 6, 8-11, 13-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 7           entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3                 entry P          line   167 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 12             entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-31             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 12-13 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 11       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-7, 9-10   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8           entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-16       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-13  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-22 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-6, 8, 10-11, 13, 15, 17-24 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 7, 12, 14, 16                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9                               entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-41                           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-23  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-34 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 14              entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4-8, 10-11, 13, 16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9                     entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12, 15                entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-32                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-6 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7      entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-20   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-5, 7, 9-14, 16-22, 24 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 6                       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 15, 23                  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-42                      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
# ...
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6-22 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-35     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3   entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-15  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-9, 11, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 10, 12, 15       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-25               entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2    entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3    entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-8  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 10, 18-19, 21 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2                     entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5-9, 11-16, 20, 22-23 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17                    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-30                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-7         entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 11       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-10, 12-13 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14-19       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 4-5 entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-3    entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3  entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4-23  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 24-34 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 6-8, 10-12, 14-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 9, 13                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4                       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5                       entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-27                   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5, 7-8 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6          entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-20          entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 9     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-6, 8   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7, 10-11 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-17    entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5      entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6-10   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 5            entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 4, 6-7, 9-10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 8, 11        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12-21           entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-7, 9-10, 13, 16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 15                  entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8, 11-12, 14, 17       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18-31                  entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-8, 10-12, 14, 16-17 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9, 13, 15, 19-20      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 18                    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21-31                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1         entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4, 6, 9 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5         entry BR         line   567 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-8       entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10-13     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 22-23, 25 entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-20, 24     entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 21           entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 26-38        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-3, 5-7   entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 8-9, 11 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10, 12     entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 13-24      entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-15  entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-33 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-4, 6-9, 11-13, 15-16, 18-19, 21-22, 24 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 5, 17                                    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10, 20, 23                                  entry F          line    91 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 14, 25-26                                   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 27-44                                       entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2, 4-5 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 3, 6     entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-18     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3-16 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2       entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 17-33   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 8    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-7, 10 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9       entry S          line   181 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 11-16   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 7-8 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-6    entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 9-15   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-6, 8-21 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7         entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 22-42     entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 3, 5-11, 14-19, 21-22, 24 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2, 12-13, 20                 entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 4, 23                        entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 25-44                        entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 7   entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 8-19   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-9, 11, 13-19, 21-22 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 10, 12                entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 20                    entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 23-39                 entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4, 6 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5      entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 7-14   entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#
#    => Loading Basis Set <=
#
#     Name: STO-3G
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1, 7-8            entry O          line    81 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 2-4, 10-11, 13-14 entry C          line    61 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 5, 9              entry N          line    71 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 6                 entry P          line   167 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 12, 15            entry CL         line   195 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs
#     atoms 16-32             entry H          line    19 file /home/kuma/anaconda3/envs/chem/share/psi4/basis/sto-3g.gbs

# %%
#データのリスト化とソート
data_sets = pd.DataFrame({'ID': ID_list, 'wavefunction': wavefunction_list})
data_sets = data_sets.sort_values('ID')
sort_data_sets = data_sets.reset_index(drop=True)
print(sort_data_sets)
# Out:
#         ID                                       wavefunction
# 0        1  <psi4.core.Wavefunction object at 0x7f085d423830>
# 1        2  <psi4.core.Wavefunction object at 0x7f08495ce650>
# 2        3  <psi4.core.Wavefunction object at 0x7f0864edf110>
# 3        4  <psi4.core.Wavefunction object at 0x7f0868ead170>
# 4        5  <psi4.core.Wavefunction object at 0x7f084ab2e6b0>
# ...    ...                                                ...
# 1478  1661  <psi4.core.Wavefunction object at 0x7f085d423110>
# 1479  1663  <psi4.core.Wavefunction object at 0x7f08683eec50>
# 1480  1664  <psi4.core.Wavefunction object at 0x7f084eb66cb0>
# 1481  1666  <psi4.core.Wavefunction object at 0x7f0868300770>
# 1482  1667  <psi4.core.Wavefunction object at 0x7f084d2f4890>
#
# [1483 rows x 2 columns]

# %%
#元データの読み込み
original_df = pd.read_csv( '../calculation/Ames_data/AvailableAmesDataSets.csv')
print('original data has {} molecules'.format(len(original_df.index))) #6506
print(original_df)
# Out:
# original data has 6506 molecules
#       Unnamed: 0    ID                                             smiles  \
# 0              0     1  O=C1c2ccccc2C(=O)c3c1ccc4c3[nH]c5c6C(=O)c7cccc...
# 1              1     2  CC(=O)OC1(CCC2C3C=C(Cl)C4=CC(=O)OCC4(C)C3CCC12...
# 2              2     3                                    Nc1nc(N)nc(N)n1
# 3              3     4      Cc1ccc(N=Nc2c(O)ccc3ccccc23)c(c1)[N+](=O)[O-]
# 4              4     5                          CC(C)CC(=O)Nc1snc2ccccc12
# ...          ...   ...                                                ...
# 6501        6501  6502  COC1COC(COCC2COC(OC)C(OS(=O)(=O)O)C2OS(=O)(=O)...
# 6502        6502  6503                      OC(Cc1cn(N=O)c2ccccc12)C(=O)O
# 6503        6503  6504                           COC(=O)Nc1nc2ccccc2[nH]1
# 6504        6504  6505                      ClCc1cccc2c3cccc4cccc(c12)c34
# 6505        6505  6506                                       CCCN(CCC)N=O
#
#       activity
# 0            0
# 1            0
# 2            0
# 3            1
# 4            0
# ...        ...
# 6501         0
# 6502         1
# 6503         1
# 6504         1
# 6505         1
#
# [6506 rows x 4 columns]

# %%
#smiles & activityの取得
smiles_list = []
act_list = []
for ID in sort_data_sets.ID :
    same_df = original_df.query('ID == @ID')
    smile = same_df['smiles'].values[0]
    act = same_df['activity'].values[0]
    smiles_list.append(smile)
    act_list.append(float(act))
    
sort_data_sets['smiles'] = smiles_list
sort_data_sets['activity'] = act_list
print(sort_data_sets)
# Out:
#         ID                                       wavefunction  \
# 0        1  <psi4.core.Wavefunction object at 0x7f085d423830>
# 1        2  <psi4.core.Wavefunction object at 0x7f08495ce650>
# 2        3  <psi4.core.Wavefunction object at 0x7f0864edf110>
# 3        4  <psi4.core.Wavefunction object at 0x7f0868ead170>
# 4        5  <psi4.core.Wavefunction object at 0x7f084ab2e6b0>
# ...    ...                                                ...
# 1478  1661  <psi4.core.Wavefunction object at 0x7f085d423110>
# 1479  1663  <psi4.core.Wavefunction object at 0x7f08683eec50>
# 1480  1664  <psi4.core.Wavefunction object at 0x7f084eb66cb0>
# 1481  1666  <psi4.core.Wavefunction object at 0x7f0868300770>
# 1482  1667  <psi4.core.Wavefunction object at 0x7f084d2f4890>
#
#                                                  smiles  activity
# 0     O=C1c2ccccc2C(=O)c3c1ccc4c3[nH]c5c6C(=O)c7cccc...       0.0
# 1     CC(=O)OC1(CCC2C3C=C(Cl)C4=CC(=O)OCC4(C)C3CCC12...       0.0
# 2                                       Nc1nc(N)nc(N)n1       0.0
# 3         Cc1ccc(N=Nc2c(O)ccc3ccccc23)c(c1)[N+](=O)[O-]       1.0
# 4                             CC(C)CC(=O)Nc1snc2ccccc12       0.0
# ...                                                 ...       ...
# 1478               CCC1(CC(=O)O)OCCc2c1[nH]c3c(C)cccc23       0.0
# 1479                      C[N+]1([O-])CCC(=CC1)c2ccccc2       0.0
# 1480       CC(=O)Nc1ccc(NC(=O)C)c2C(=O)c3ccccc3C(=O)c12       1.0
# 1481                               CNc1c(C)cc2ncccc2c1N       0.0
# 1482                                   COc1nncc2ccccc12       0.0
#
# [1483 rows x 4 columns]

# %%
#activityのカウント
pd.value_counts(sort_data_sets.activity)
# Out:
# 1.0    789
# 0.0    694
# Name: activity, dtype: int64

# %%
"""
1.0    789
0.0    694
Name: activity, dtype: int64
"""

# %%
#detaの分割
from sklearn.model_selection import train_test_split
train_val, test = train_test_split(sort_data_sets, random_state=0)
train, val = train_test_split(train_val)

# %%
"""
///////wavefunctionの導入///////
"""

# %%
## pandasのデータフレームからRDkitのmolオブジェクトXとラベルYのペアに変換

Xwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Ywf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
Zwf={dataset_keyword:[] for dataset_keyword in ["train","valid","test"]}
for (smile, act, wf) in zip(train.smiles, train.activity, train.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol)  
    Xwf["train"].append(mol)
    Ywf["train"].append(act)
    Zwf["train"].append(wf)
for (smile, act, wf) in zip(val.smiles, val.activity, val.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol) 
    Xwf["valid"].append(mol)
    Ywf["valid"].append(act)
    Zwf["valid"].append(wf)
for (smile, act, wf) in zip(test.smiles, test.activity, test.wavefunction):
    mol = Chem.MolFromSmiles(smile)
    mol = Chem.AddHs(mol) 
    Xwf["test"].append(mol)
    Ywf["test"].append(act)
    Zwf["test"].append(wf)

# %%
def one_of_k_encoding(x, allowable_set):
    if x not in allowable_set:
        raise Exception(
            "input {0} not in allowable set{1}:".format(x, allowable_set))
    return list(map(lambda s: x == s, allowable_set))


def one_of_k_encoding_unk(x, allowable_set):
    """Maps inputs not in the allowable set to the last element."""
    if x not in allowable_set:
        x = allowable_set[-1]
    return list(map(lambda s: x == s, allowable_set))

def get_atom_features(atom, en_list=None, explicit_H=False, use_sybyl=False, use_electronegativity=False,
                  use_gasteiger=False, degree_dim=17):
    if use_sybyl:
        atom_type = ordkit._sybyl_atom_type(atom)
        atom_list = ['C.ar', 'C.cat', 'C.1', 'C.2', 'C.3', 'N.ar', 'N.am', 'N.pl3', 'N.1', 'N.2', 'N.3', 'N.4', 'O.co2',
                     'O.2', 'O.3', 'S.O', 'S.o2', 'S.2', 'S.3', 'F', 'Si', 'P', 'P3', 'Cl', 'Br', 'Mg', 'Na', 'Ca',
                     'Fe', 'As', 'Al', 'I', 'B', 'V', 'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn',
                     'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni', 'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    else:
        atom_type = atom.GetSymbol()
        atom_list = ['C', 'N', 'O', 'S', 'F', 'Si', 'P', 'Cl', 'Br', 'Mg', 'Na', 'Ca', 'Fe', 'As', 'Al', 'I', 'B', 'V',
                     'K', 'Tl', 'Yb', 'Sb', 'Sn', 'Ag', 'Pd', 'Co', 'Se', 'Ti', 'Zn', 'H', 'Li', 'Ge', 'Cu', 'Au', 'Ni',
                     'Cd', 'In', 'Mn', 'Zr', 'Cr', 'Pt', 'Hg', 'Pb', 'Unknown']
    results = one_of_k_encoding_unk(atom_type, atom_list) + \
        one_of_k_encoding(atom.GetDegree(), list(range(degree_dim))) + \
        one_of_k_encoding_unk(atom.GetImplicitValence(), [0, 1, 2, 3, 4, 5, 6]) + \
        [atom.GetFormalCharge(), atom.GetNumRadicalElectrons()] + \
        one_of_k_encoding_unk(atom.GetHybridization(),
                              [Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
                               Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.SP3D,
                               Chem.rdchem.HybridizationType.SP3D2]) + \
        [atom.GetIsAromatic()]

    if use_electronegativity:
        results = results + [en_list[atom.GetAtomicNum() - 1]]
    if use_gasteiger:
        gasteiger = atom.GetDoubleProp('_GasteigerCharge')
        if np.isnan(gasteiger) or np.isinf(gasteiger):
            gasteiger = 0  # because the mean is 0
        results = results + [gasteiger]

    # In case of explicit hydrogen(QM8, QM9), avoid calling `GetTotalNumHs`
    if not explicit_H:
        results = results + one_of_k_encoding_unk(atom.GetTotalNumHs(), [0, 1, 2, 3, 4])
    return np.array(results, dtype=np.float32)

def get_bond_features(bond):
  results=one_of_k_encoding_unk(bond.GetBondType(),[Chem.rdchem.BondType.SINGLE,
                         Chem.rdchem.BondType.DOUBLE,
                         Chem.rdchem.BondType.TRIPLE,
                         Chem.rdchem.BondType.AROMATIC])
  return np.array(results, dtype=np.float32)

# %%
import torch
from rdkit import Chem
from torch_geometric.data import Data as TorchGeometricData
from torch_geometric.data import DataLoader

def get_edge_features(mol):
    edge_list= []
    num_bond_features=0
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        bond_features = get_bond_features(bond)
        num_bond_features=len(bond_features)
        edge_list += [([i, j],bond_features), ([j, i],bond_features)]
    return edge_list, num_bond_features

#modified mol2geodata
#規格化関数
def rescaling(features):
    norm_features = []
    max_value = max(features)
    min_value = min(features)
    for feature in features:
        norm_feature = (feature - min_value)/(max_value - min_value)
        norm_features.append(norm_feature)
    
    return norm_features

def get_WF_results(wf):
    #Mulliken電荷
    psi4.oeprop(wf, "MULLIKEN_CHARGES")
    M_charges = np.array(wf.atomic_point_charges())
    norm_M_charges = rescaling(M_charges)
    #Löwdin電荷
    psi4.oeprop(wf, "LOWDIN_CHARGES")
    L_charges = np.array(wf.atomic_point_charges())
    norm_L_charges = rescaling(L_charges)
    #wf_molecule
    wf_mol = wf.molecule()
    wf_atom_num = wf_mol.natom()
    x_dem_list = []
    y_dem_list = []
    z_dem_list = []
    for num in list(range(wf_atom_num)):
        xyz = wf_mol.xyz(num)
        #x
        if xyz[0] < 0:
            x_dem_list.append(0)
        else:
            x_dem_list.append(1)
        #y
        if xyz[1] < 0:
            y_dem_list.append(0)
        else:
            y_dem_list.append(1)
        #z
        if xyz[2] < 0:
            z_dem_list.append(0)
        else:
            z_dem_list.append(1)
    x_dems = np.array(x_dem_list)
    y_dems = np.array(y_dem_list)
    z_dems = np.array(z_dem_list)
    #結果のまとめ                           
    WF_results = [np.array([Mcharge,Lcharge,x_dem,y_dem,z_dem], dtype=np.float32) for (Mcharge,Lcharge,x_dem,y_dem,z_dem) in zip(norm_M_charges, norm_L_charges,x_dems,y_dems,z_dems)]
    
    return WF_results

def mol2geodataWF(mol,y,z):
    smile = Chem.MolToSmiles(mol)
    atom_features =[get_atom_features(atom) for atom in mol.GetAtoms()]
    WF_results = get_WF_results(z)
    atom_features = np.append(atom_features, WF_results, axis=1)
    num_atom_features=len(atom_features[0])
    atom_features = torch.FloatTensor(atom_features).view(-1, len(atom_features[0]))

    edge_list,num_bond_features = get_edge_features(mol)
    edge_list=sorted(edge_list)
    
    edge_indices=[e for e,v in edge_list]
    edge_attributes=[v for e,v in edge_list]
    edge_indices = torch.tensor(edge_indices)
    edge_indices = edge_indices.t().to(torch.long).view(2, -1)
    edge_attributes = torch.FloatTensor(edge_attributes)
    #print(num_atom_features,num_bond_features)
    return TorchGeometricData(x=atom_features, edge_index=edge_indices, edge_attr=edge_attributes, num_atom_features=num_atom_features,num_bond_features=num_bond_features,smiles=smile, y=y)

# %%
train_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["train"],Ywf["train"],Zwf["train"])]
train_loader = DataLoader(train_data_list, batch_size=128,shuffle=True)

valid_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["valid"],Ywf["valid"],Zwf["valid"])]
valid_loader = DataLoader(valid_data_list, batch_size=128,shuffle=True)

test_data_list = [mol2geodataWF(mol,y,z) for mol,y,z in zip(Xwf["test"],Ywf["test"],Zwf["test"])]
test_loader = DataLoader(test_data_list, batch_size=128,shuffle=True)
# Out:
# /home/kuma/anaconda3/envs/chem/lib/python3.7/site-packages/torch_geometric/deprecation.py:13: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
#data check
print(train_data_list[0].smiles)
print(train_data_list[0].x[0])
# Out:
# [H]c1c([H])c([H])c2c(c1[H])c([H])c([H])c1c(C([H])([H])[H])c3c([H])c(C([H])([H])[H])c(C([H])([H])[H])c([H])c3nc12
# tensor([1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000,
#         0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         1.0000, 0.0000, 0.0000, 0.0000, 1.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.2054, 0.3658, 0.0000, 1.0000, 1.0000])

# %%
num_atom_features = train_data_list[0].num_atom_features
num_bond_features = train_data_list[0].num_bond_features

print("num_atom_features =",num_atom_features)
print("num_bond_features =",num_bond_features)
# Out:
# num_atom_features = 86
# num_bond_features = 4

# %%
# ニューラルネットワークの構造の定義

import torch
import torch.nn.functional as F
from torch.nn import Sequential, Linear, ReLU, GRU
import torch_geometric.transforms as T
from torch_geometric.nn import NNConv, Set2Set

dim = 64 # 中間層の次元

class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.lin0 = torch.nn.Linear(num_atom_features, dim)

        nn = Sequential(Linear(num_bond_features, 128), ReLU(), Linear(128, dim * dim))
        self.conv = NNConv(dim, dim, nn, aggr='mean')
        self.gru = GRU(dim, dim)

        self.set2set = Set2Set(dim, processing_steps=3)
        self.lin1 = torch.nn.Linear(2 * dim, dim)
        self.lin2 = torch.nn.Linear(dim, 1)

    def forward(self, data):
        out = F.relu(self.lin0(data.x))
        h = out.unsqueeze(0)

        for i in range(3):
            m = F.relu(self.conv(out, data.edge_index, data.edge_attr))
            out, h = self.gru(m.unsqueeze(0), h)
            out = out.squeeze(0)

        out = self.set2set(out, data.batch)
        out = F.relu(self.lin1(out))
        out = self.lin2(out)
        return out.view(-1)

# %%
# ニューラルネットワークの学習パラメータの定義

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',factor=0.7, patience=5,min_lr=0.00001)
loss_function = torch.nn.BCEWithLogitsLoss()

def train_step(epoch):
    model.train()
    loss_all = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        loss = loss_function(model(data), data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_loader.dataset)

def test_step(loader):
    model.eval()
    loss_all = 0
    for data in loader:
        data = data.to(device)
        loss = loss_function(model(data), data.y)
        loss_all += loss.item() * data.num_graphs
    return loss_all / len(loader.dataset)

# %%
# 学習開始

best_valid_loss = None
for epoch in range(1, 10):
    lr = scheduler.optimizer.param_groups[0]['lr']
    loss = train_step(epoch)
    valid_loss = test_step(valid_loader)
    scheduler.step(valid_loss)

    if best_valid_loss is None or valid_loss <= best_valid_loss:
        test_loss = test_step(test_loader)
        best_valid_loss = valid_loss

    print('Epoch: {:03d}, LR: {:7f}, Loss: {:.7f}, Validation loss: {:.7f}, '
          'Test loss: {:.7f}'.format(epoch, lr, loss, valid_loss, test_loss))
# Out:
# Epoch: 001, LR: 0.001000, Loss: 0.6915739, Validation loss: 0.6854131, Test loss: 0.6842396
# Epoch: 002, LR: 0.001000, Loss: 0.6806009, Validation loss: 0.6797727, Test loss: 0.6695056
# Epoch: 003, LR: 0.001000, Loss: 0.6654086, Validation loss: 0.6808462, Test loss: 0.6695056
# Epoch: 004, LR: 0.001000, Loss: 0.6620982, Validation loss: 0.6758467, Test loss: 0.6657843
# Epoch: 005, LR: 0.001000, Loss: 0.6624721, Validation loss: 0.6710936, Test loss: 0.6631498
# Epoch: 006, LR: 0.001000, Loss: 0.6603806, Validation loss: 0.6668497, Test loss: 0.6578497
# Epoch: 007, LR: 0.001000, Loss: 0.6508664, Validation loss: 0.6566945, Test loss: 0.6485058
# Epoch: 008, LR: 0.001000, Loss: 0.6447659, Validation loss: 0.6723924, Test loss: 0.6485058
# Epoch: 009, LR: 0.001000, Loss: 0.6431543, Validation loss: 0.6426831, Test loss: 0.6219370

# %%
test_ID = sort_data_sets.ID[2]
test_wf = sort_data_sets.wavefunction[2]
test_smile = sort_data_sets.smiles[2]
test_mol = Chem.MolFromSmiles(test_smile)
test_mol = Chem.AddHs(test_mol) 
test_wf_mol = test_wf.molecule()
test_wf_atom_num = test_wf_mol.natom()
print('ID: ', test_ID)
print('wavefunction: ', test_wf)
print('smiles: ', test_smile)
print('MOL: ', test_mol)
print('atom_num(WF)', test_wf_atom_num)
test_wf_mol.print_out()
# Out:
# ID:  3
# wavefunction:  <psi4.core.Wavefunction object at 0x7f6ab55e1f50>
# smiles:  Nc1nc(N)nc(N)n1
# MOL:  <rdkit.Chem.rdchem.Mol object at 0x7f6a93fdc6c0>
# atom_num(WF) 15

# %%
#Mulliken電荷
psi4.oeprop(test_wf, "MULLIKEN_CHARGES")
M_charges = np.array(test_wf.atomic_point_charges())
norm_M_charges = rescaling(M_charges)
#Löwdin電荷
psi4.oeprop(test_wf, "LOWDIN_CHARGES")
L_charges = np.array(test_wf.atomic_point_charges())
norm_L_charges = rescaling(L_charges)
                               
test_WF_results = [np.array([Mcharge,Lcharge], dtype=np.float32) for (Mcharge,Lcharge) in zip(norm_M_charges, norm_L_charges)]
print(test_WF_results)
# Out:
# [array([0.00030145, 0.09754255], dtype=float32), array([1., 1.], dtype=float32), array([0.08886396, 0.        ], dtype=float32), array([1., 1.], dtype=float32), array([0.00030145, 0.09754255], dtype=float32), array([0.0893366 , 0.00082777], dtype=float32), array([0.99901557, 0.9988996 ], dtype=float32), array([0.        , 0.09635445], dtype=float32), array([0.08933661, 0.00082778], dtype=float32), array([0.83078665, 0.78879106], dtype=float32), array([0.83121365, 0.78925085], dtype=float32), array([0.83078665, 0.78879106], dtype=float32), array([0.83121365, 0.78925085], dtype=float32), array([0.8307696 , 0.78884184], dtype=float32), array([0.8307696 , 0.78884184], dtype=float32)]

# %%
test_mol = test_wf.molecule() #molオブジェクトの生成
test_atom_num = test_mol.natom() #atom数
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_518/3022421520.py in <module>
# ----> 1 test_mol = test_wf.molecule() #molオブジェクトの生成
#       2 test_atom_num = test_mol.natom() #atom数
#
# NameError: name 'test_wf' is not defined
